# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
  
import numpy as np
import pandas as pd
import re
#Import libraries
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt
# %matplotlib inline
from pylab import *
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
Base_dir='/data/nandas/Transcription/KimDevTime_071620'
os.chdir(Base_dir)
from scipy.signal import find_peaks
# from CatExp import *
import statsmodels as st
# import statsmodels.api as sm

# %%
Tissue_dir='/data/nandas/Combined_coexp/Part_1_TranscriptionallyRegulatedGenes/Tissue/'
Kim_dir='/data/nandas/Transcription/KimDevTime_071620/'

# %%
mapper_df=pd.read_csv("/data/nandas/WormBase_282/MasterProteinCodingGenesAnnotation_WS282.csv", header='infer',
                      index_col=0)
mapper_df=mapper_df.loc[mapper_df.index.dropna()]

# %%
def wb_to_gene(matrix):
    mapper_df=pd.read_csv("/data/nandas/WormBase_282/MasterProteinCodingGenesAnnotation_WS282.csv", header='infer',index_col=1)
    mapper_df=mapper_df.loc[mapper_df.index.dropna()]
    wb_to_gene = {};
    for wb in mapper_df.index:
        wb_to_gene[wb] = str(mapper_df.loc[wb]['GeneName']);
    matrix=matrix.rename(index=wb_to_gene,columns=wb_to_gene)
    return matrix

def gene_to_wb(matrix):
    mapper_df=pd.read_csv("/data/nandas/WormBase_282/MasterProteinCodingGenesAnnotation_WS282.csv", header='infer',index_col=2)
    mapper_df=mapper_df.loc[mapper_df.index.dropna()]
    gene_to_wb = {};
    for gene in mapper_df.index:
        gene_to_wb[gene] = str(mapper_df.loc[gene]['WormBaseID']);
    matrix=matrix.rename(index=gene_to_wb,columns=gene_to_wb)
    return matrix

def SeqToWB(matrix):
    mapper_df=pd.read_csv("/data/nandas/WormBase_282/MasterProteinCodingGenesAnnotation_WS282.csv", header='infer',index_col=3)
    mapper_df=mapper_df.loc[mapper_df.index.dropna()]
    Seq_to_Wb = {};
    mapper_df=mapper_df[mapper_df.index!=np.nan]
    for seq in mapper_df.index:
        Seq_to_Wb[seq] = str(mapper_df.loc[seq]['WormBaseID']);
    matrix=matrix.rename(index=Seq_to_Wb,columns=Seq_to_Wb)
    return matrix

def SeqToGene(matrix):
    mapper_df=pd.read_csv("/data/nandas/WormBase_282/MasterProteinCodingGenesAnnotation_WS282.csv", header='infer',index_col=3)
    mapper_df=mapper_df.loc[mapper_df.index.dropna()]
    Seq_to_Gene = {};
    mapper_df=mapper_df[mapper_df.index!=np.nan]
    for seq in mapper_df.index:
        Seq_to_Gene[seq] = str(mapper_df.loc[seq]['GeneName']);
    matrix=matrix.rename(index=Seq_to_Gene,columns=Seq_to_Gene)
    return matrix

# %% [markdown]
# ## Reading development and tissue binning files

# %%
VS=pd.read_csv(Kim_dir+"Binning_021222.csv",index_col=0)

# %%
CoefVar=pd.read_csv(Tissue_dir+"CVTissue_AllGenes.csv",index_col=0)

# %%
intersect=list(set(VS.index).intersection(set(CoefVar.index)))

# %%
CommonVS=VS.loc[intersect]

# %%
CommonCoefVar=CoefVar.loc[intersect]

# %%
VS
# Out:
#                 Variation Score  Gene Cluster  Bin
# WormBaseID
# WBGene00020700         1.607023           9.0    3
# WBGene00000608         1.595401           9.0    3
# WBGene00000663         1.586700           9.0    3
# WBGene00000694         1.579680           9.0    3
# WBGene00011460         1.565983           9.0    3
# ...                         ...           ...  ...
# WBGene00004306         0.000000          12.0    1
# WBGene00006715         0.000000          12.0    1
# WBGene00022785         0.000000          12.0    1
# WBGene00022192         0.000000          12.0    1
# WBGene00004408         0.000000          12.0    1
#
# [14561 rows x 3 columns]

# %%
CommonVS=CommonVS[['Variation Score','Bin']]
CommonCoefVar=CommonCoefVar[['CoefVar','Bin']]

# %%
CommonVS['DevelopmentBin']=CommonVS['Bin']

# %%
CommonCoefVar['TissueBin']=CommonCoefVar['Bin']

# %%
CommonVSCoefVar=CommonCoefVar[['CoefVar','TissueBin']]

# %%
CommonVSCoefVar[['Variation Score','DevelopmentBin']]=CommonVS[['Variation Score','DevelopmentBin']]

# %%
CommonVSCoefVar
# Out:
#                  CoefVar           TissueBin  Variation Score  DevelopmentBin
# WormBaseID
# WBGene00011985  1.659006      Highly variant         0.054513               2
# WBGene00008485  2.424174      Highly variant         0.485177               3
# WBGene00016134  2.426214      Highly variant         0.006843               2
# WBGene00000950  2.038499      Highly variant         0.013586               2
# WBGene00044029  1.145128      Highly variant         0.202503               3
# ...                  ...                 ...              ...             ...
# WBGene00011807  0.639272  Moderately variant         0.000000               1
# WBGene00022802  1.489352      Highly variant         0.275850               3
# WBGene00004503  0.387512  Moderately variant         0.015066               2
# WBGene00022018  2.093415      Highly variant         0.426845               3
# WBGene00006955  1.504948      Highly variant         0.527253               3
#
# [14556 rows x 4 columns]

# %%
CommonVS=pd.DataFrame(CommonVS)
CommonCoefVar=pd.DataFrame(CommonCoefVar)

# %%
# CommonVSCoefVar['DevelopmentBin']=str(CommonVSCoefVar['DevelopmentBin'])

# %%
CommonVSCoefVar
# Out:
#                  CoefVar           TissueBin  Variation Score  DevelopmentBin
# WormBaseID
# WBGene00011985  1.659006      Highly variant         0.054513               2
# WBGene00008485  2.424174      Highly variant         0.485177               3
# WBGene00016134  2.426214      Highly variant         0.006843               2
# WBGene00000950  2.038499      Highly variant         0.013586               2
# WBGene00044029  1.145128      Highly variant         0.202503               3
# ...                  ...                 ...              ...             ...
# WBGene00011807  0.639272  Moderately variant         0.000000               1
# WBGene00022802  1.489352      Highly variant         0.275850               3
# WBGene00004503  0.387512  Moderately variant         0.015066               2
# WBGene00022018  2.093415      Highly variant         0.426845               3
# WBGene00006955  1.504948      Highly variant         0.527253               3
#
# [14556 rows x 4 columns]

# %%
LowExpKim=pd.read_csv(Kim_dir+"LowExp_Kim.csv",index_col=0)

# %%
LowExpKim
# Out:
#                 DH2_N2_0  DH2_N2_2  DH2_N2_4  DH2_N2_6  DH2_N2_8  DH2_N2_10  \
# WormBaseID
# WBGene00012335  1.012198  1.489701  0.738886  0.629337  0.171848   0.097373
# WBGene00005169  0.303189  0.364411  0.484143  0.659780  0.360321   0.204166
# WBGene00005565  0.257818       NaN  0.082339  0.224419  0.076600        NaN
# WBGene00001667  0.507856  0.627847  0.681209  0.618892  0.482845   0.444585
# WBGene00018443  0.059516  0.490518  0.114045  0.103612  0.070731   0.040078
# ...                  ...       ...       ...       ...       ...        ...
# WBGene00007727       NaN  0.054514  0.135194  0.046060       NaN        NaN
# WBGene00044284  0.280497  0.192650  0.477768       NaN       NaN        NaN
# WBGene00005081  1.653349  0.879133  0.579125  0.417822  0.380304   0.395063
# WBGene00019553       NaN  0.957339  0.118709  0.161774       NaN   0.125151
# WBGene00015121       NaN  0.832246  1.031978       NaN       NaN   0.181330
#
#                 DH2_N2_12  DH2_N2_14  DH2_N2_16  DH2_N2_18  ...  DH2_N2_32  \
# WormBaseID                                                  ...
# WBGene00012335   0.098352   0.228040   0.179612        NaN  ...        NaN
# WBGene00005169   0.206219   0.159381   0.062767        NaN  ...   0.080979
# WBGene00005565        NaN        NaN        NaN        NaN  ...        NaN
# WBGene00001667   0.656312   0.480547   1.324733   0.544404  ...   0.461189
# WBGene00018443   0.080962        NaN   0.147854        NaN  ...        NaN
# ...                   ...        ...        ...        ...  ...        ...
# WBGene00007727   0.071982   0.041724        NaN        NaN  ...        NaN
# WBGene00044284        NaN        NaN   0.232276        NaN  ...   0.249727
# WBGene00005081   0.253932   0.336439   0.132496   0.142930  ...   0.085470
# WBGene00019553   0.252819        NaN        NaN   0.249032  ...        NaN
# WBGene00015121        NaN        NaN        NaN        NaN  ...        NaN
#
#                 DH2_N2_34  DH2_N2_36  DH2_N2_38  DH5_N2_38  DH5_N2_40  \
# WormBaseID
# WBGene00012335   0.084695   0.065306        NaN        NaN        NaN
# WBGene00005169   0.147987   0.136929   0.161941   0.213330   0.188588
# WBGene00005565        NaN        NaN        NaN        NaN        NaN
# WBGene00001667   0.446195   0.435791        NaN   0.428805   0.379073
# WBGene00018443        NaN   0.026879        NaN   0.031407        NaN
# ...                   ...        ...        ...        ...        ...
# WBGene00007727        NaN        NaN        NaN        NaN        NaN
# WBGene00044284        NaN        NaN        NaN        NaN        NaN
# WBGene00005081   0.187433   0.120436   0.170921   0.140725   0.099523
# WBGene00019553        NaN        NaN        NaN        NaN        NaN
# WBGene00015121        NaN        NaN        NaN   0.142101        NaN
#
#                 DH5_N2_42  DH5_N2_44  DH5_N2_46  DH5_N2_48
# WormBaseID
# WBGene00012335        NaN        NaN        NaN        NaN
# WBGene00005169   0.056753   0.057094   0.056694   0.023326
# WBGene00005565        NaN        NaN        NaN        NaN
# WBGene00001667   0.399269   0.487741   0.256407   0.164103
# WBGene00018443        NaN        NaN   0.033387        NaN
# ...                   ...        ...        ...        ...
# WBGene00007727        NaN   0.029893   0.178104   0.195409
# WBGene00044284   0.210021   0.105642        NaN        NaN
# WBGene00005081   0.119801   0.210911   0.179515   0.295435
# WBGene00019553   0.104366        NaN        NaN        NaN
# WBGene00015121   0.151215        NaN        NaN        NaN
#
# [3552 rows x 26 columns]

# %%
list(set(LowExpKim.index).intersection(set(CommonVSCoefVar.index)))
# Out:
# []

# %%
(CommonVSCoefVar['DevelopmentBin']).replace(3,'Highly variant',inplace=True)
(CommonVSCoefVar['DevelopmentBin']).replace(2,'Moderately variant',inplace=True)
(CommonVSCoefVar['DevelopmentBin']).replace(1,'Invariant',inplace=True)

# %%
np.unique(CommonVSCoefVar.TissueBin)
# Out:
# array(['Highly variant', 'Invariant', 'Lowly expressed',
#        'Moderately variant'], dtype=object)

# %%
CommonVSCoefVar[CommonVSCoefVar.TissueBin=='Lowly expressed']
# Out:
#                 CoefVar        TissueBin  Variation Score      DevelopmentBin
# WormBaseID
# WBGene00016008      NaN  Lowly expressed         0.103095  Moderately variant
# WBGene00022654      NaN  Lowly expressed         0.951210      Highly variant
# WBGene00019364      NaN  Lowly expressed         0.155110  Moderately variant
# WBGene00008336      NaN  Lowly expressed         0.141996  Moderately variant
# WBGene00018601      NaN  Lowly expressed         0.755670      Highly variant
# ...                 ...              ...              ...                 ...
# WBGene00008597      NaN  Lowly expressed         0.439219      Highly variant
# WBGene00021407      NaN  Lowly expressed         0.471329      Highly variant
# WBGene00001108      NaN  Lowly expressed         1.030730      Highly variant
# WBGene00001625      NaN  Lowly expressed         0.200621      Highly variant
# WBGene00008660      NaN  Lowly expressed         1.118556      Highly variant
#
# [2382 rows x 4 columns]

# %%
for genes in CommonVSCoefVar.index:
#     print(genes)
    if genes in LowExpKim.index:
        print(genes)
        CommonVSCoefVar.at[genes,'DevelopmentBin']='Lowly expressed'
        print(CommonVSCoefVar.loc[genes,'DevelopmentBin'])
#     elif (CommonVSCoefVar.loc[genes,'DevelopmentBin'])==1:
#         CommonVSCoefVar.at[genes,'DevelopmentBin']='Invariant'
#     elif (CommonVSCoefVar.loc[genes,'DevelopmentBin'])==3:
#         print(type((CommonVSCoefVar.loc[genes,'DevelopmentBin'])))
#         CommonVSCoefVar.at[genes,'DevelopmentBin']='Highly variant'
#     elif (CommonVSCoefVar.loc[genes,'DevelopmentBin'])==2:
#         CommonVSCoefVar.at[genes,'DevelopmentBin']='Moderately variant'

# %%
np.unique(CommonVSCoefVar.DevelopmentBin)
# Out:
# array(['Highly variant', 'Invariant', 'Moderately variant'], dtype=object)

# %% [markdown]
# ## Removing genes that are lowly expressed in both development and tissues

# %%
count=0
for genes in CommonVSCoefVar.index:
    if (CommonVSCoefVar.loc[genes,'DevelopmentBin'])=='Lowly expressed' :
        if  (CommonVSCoefVar.loc[genes,'TissueBin'])=='Lowly expressed':
            print(genes)
            count=count+1
            print(count)
            CommonVSCoefVar.drop(index=genes,inplace=True)

# %%
CommonVSCoefVar
# Out:
#                  CoefVar           TissueBin  Variation Score  \
# WormBaseID
# WBGene00011985  1.659006      Highly variant         0.054513
# WBGene00008485  2.424174      Highly variant         0.485177
# WBGene00016134  2.426214      Highly variant         0.006843
# WBGene00000950  2.038499      Highly variant         0.013586
# WBGene00044029  1.145128      Highly variant         0.202503
# ...                  ...                 ...              ...
# WBGene00011807  0.639272  Moderately variant         0.000000
# WBGene00022802  1.489352      Highly variant         0.275850
# WBGene00004503  0.387512  Moderately variant         0.015066
# WBGene00022018  2.093415      Highly variant         0.426845
# WBGene00006955  1.504948      Highly variant         0.527253
#
#                     DevelopmentBin
# WormBaseID
# WBGene00011985  Moderately variant
# WBGene00008485      Highly variant
# WBGene00016134  Moderately variant
# WBGene00000950  Moderately variant
# WBGene00044029      Highly variant
# ...                            ...
# WBGene00011807           Invariant
# WBGene00022802      Highly variant
# WBGene00004503  Moderately variant
# WBGene00022018      Highly variant
# WBGene00006955      Highly variant
#
# [14556 rows x 4 columns]

# %% [markdown]
# ## Quadrant enrichment of all genes

# %%
for gene in CommonVSCoefVar.index:
    CV=CommonVSCoefVar.loc[gene]['TissueBin']
    VS=CommonVSCoefVar.loc[gene]['DevelopmentBin']
    if VS=='Highly variant' and CV=='Highly variant':
        CommonVSCoefVar.at[gene,'Quadrant']=4
    elif VS=='Highly variant' and CV!='Highly variant':
        CommonVSCoefVar.at[gene,'Quadrant']=2
    elif VS!='Highly variant' and CV=='Highly variant':
        CommonVSCoefVar.at[gene,'Quadrant']=3
    else:
        CommonVSCoefVar.at[gene,'Quadrant']=1

# %%
MetabolicClasses=pd.read_csv("/data/nandas/MetabolicClasses_August_SN_090221.csv",index_col=0)

# %%
CommonVSCoefVar
# Out:
#                  CoefVar           TissueBin  Variation Score  \
# WormBaseID
# WBGene00011985  1.659006      Highly variant         0.054513
# WBGene00008485  2.424174      Highly variant         0.485177
# WBGene00016134  2.426214      Highly variant         0.006843
# WBGene00000950  2.038499      Highly variant         0.013586
# WBGene00044029  1.145128      Highly variant         0.202503
# ...                  ...                 ...              ...
# WBGene00011807  0.639272  Moderately variant         0.000000
# WBGene00022802  1.489352      Highly variant         0.275850
# WBGene00004503  0.387512  Moderately variant         0.015066
# WBGene00022018  2.093415      Highly variant         0.426845
# WBGene00006955  1.504948      Highly variant         0.527253
#
#                     DevelopmentBin  Quadrant
# WormBaseID
# WBGene00011985  Moderately variant       3.0
# WBGene00008485      Highly variant       4.0
# WBGene00016134  Moderately variant       3.0
# WBGene00000950  Moderately variant       3.0
# WBGene00044029      Highly variant       4.0
# ...                            ...       ...
# WBGene00011807           Invariant       1.0
# WBGene00022802      Highly variant       4.0
# WBGene00004503  Moderately variant       1.0
# WBGene00022018      Highly variant       4.0
# WBGene00006955      Highly variant       4.0
#
# [14556 rows x 5 columns]

# %%
CommonVSCoefVar['Class']=MetabolicClasses['Class']

# %%
CommonVSCoefVar.Class.sort_values(ascending=False)
# Out:
# WormBaseID
# WBGene00021148      D
# WBGene00022191      D
# WBGene00044546      D
# WBGene00019236      D
# WBGene00018523      D
#                  ...
# WBGene00011807    NaN
# WBGene00022802    NaN
# WBGene00004503    NaN
# WBGene00022018    NaN
# WBGene00006955    NaN
# Name: Class, Length: 14556, dtype: object

# %%
CommonVSCoefVar
# Out:
#                  CoefVar           TissueBin  Variation Score  \
# WormBaseID
# WBGene00011985  1.659006      Highly variant         0.054513
# WBGene00008485  2.424174      Highly variant         0.485177
# WBGene00016134  2.426214      Highly variant         0.006843
# WBGene00000950  2.038499      Highly variant         0.013586
# WBGene00044029  1.145128      Highly variant         0.202503
# ...                  ...                 ...              ...
# WBGene00011807  0.639272  Moderately variant         0.000000
# WBGene00022802  1.489352      Highly variant         0.275850
# WBGene00004503  0.387512  Moderately variant         0.015066
# WBGene00022018  2.093415      Highly variant         0.426845
# WBGene00006955  1.504948      Highly variant         0.527253
#
#                     DevelopmentBin  Quadrant Class
# WormBaseID
# WBGene00011985  Moderately variant       3.0   NaN
# WBGene00008485      Highly variant       4.0     A
# WBGene00016134  Moderately variant       3.0   NaN
# WBGene00000950  Moderately variant       3.0   NaN
# WBGene00044029      Highly variant       4.0   NaN
# ...                            ...       ...   ...
# WBGene00011807           Invariant       1.0   NaN
# WBGene00022802      Highly variant       4.0   NaN
# WBGene00004503  Moderately variant       1.0   NaN
# WBGene00022018      Highly variant       4.0   NaN
# WBGene00006955      Highly variant       4.0   NaN
#
# [14556 rows x 6 columns]

# %%
AllGenesQuadrant1=CommonVSCoefVar[CommonVSCoefVar.Quadrant==1]
AllGenesQuadrant2=CommonVSCoefVar[CommonVSCoefVar.Quadrant==2]
AllGenesQuadrant3=CommonVSCoefVar[CommonVSCoefVar.Quadrant==3]
AllGenesQuadrant4=CommonVSCoefVar[CommonVSCoefVar.Quadrant==4]

# %%
totalmetabolic=list(set(CommonVSCoefVar.index).intersection(set(MetabolicClasses.index)))

# %%
MetabolicCommonVSCoefVar=CommonVSCoefVar.loc[totalmetabolic]

# %%
MetabolicCommonVSCoefVar['WormBase ID']=MetabolicCommonVSCoefVar.index

# %%
MetabolicCommonVSCoefVar=wb_to_gene(MetabolicCommonVSCoefVar)

# %%
MetabolicCommonVSCoefVar.to_csv("QuadrantCategoriesMetabolic.csv")

# %%
metabolicq1=list(set(MetabolicClasses.index).intersection(set(AllGenesQuadrant1.index)))
MetabolicGenesQuadrant1=AllGenesQuadrant1.loc[metabolicq1]

# %%
metabolicq2=list(set(MetabolicClasses.index).intersection(set(AllGenesQuadrant2.index)))
MetabolicGenesQuadrant2=AllGenesQuadrant2.loc[metabolicq2]
metabolicq3=list(set(MetabolicClasses.index).intersection(set(AllGenesQuadrant3.index)))
MetabolicGenesQuadrant3=AllGenesQuadrant3.loc[metabolicq3]
metabolicq4=list(set(MetabolicClasses.index).intersection(set(AllGenesQuadrant4.index)))
MetabolicGenesQuadrant4=AllGenesQuadrant4.loc[metabolicq4]

# %%
len(AllGenesQuadrant2.index)
# Out:
# 2346

# %%
PercentageQ1=(len(metabolicq1)*100)/len(AllGenesQuadrant1.index)
PercentageQ2=(len(metabolicq2)*100)/len(AllGenesQuadrant2.index)
PercentageQ3=(len(metabolicq3)*100)/len(AllGenesQuadrant3.index)
PercentageQ4=(len(metabolicq4)*100)/len(AllGenesQuadrant4.index)

# %%
PercentageQ4
# Out:
# 12.15504529176322

# %%
def hypergeom(x,M,n,N):
    #M is the population size (previously N)
    #n is the number of successes in the population (previously K)
    #N is the sample size (previously n)
    #X is still the number of drawn “successes”.
    from scipy.stats import hypergeom
    pval = hypergeom.sf(x-1, M, n, N)
    return pval

# %%
len(totalmetabolic)/len(CommonVSCoefVar.index)
# Out:
# 0.1499725199230558

# %%
len(totalmetabolic)
# Out:
# 2183

# %%
pvalq1=hypergeom(x=len(metabolicq1),N=len(AllGenesQuadrant1.index),n=len(totalmetabolic),
                 M=len((CommonVSCoefVar.index)))

# %%
pvalq2=hypergeom(x=len(metabolicq2),N=len(AllGenesQuadrant2.index),n=len(totalmetabolic),
                 M=len((CommonVSCoefVar.index)))

# %%
pvalq3=hypergeom(x=len(metabolicq3),N=len(AllGenesQuadrant3.index),n=len(totalmetabolic),
                 M=len((CommonVSCoefVar.index)))

# %%
pvalq4=hypergeom(x=len(metabolicq4),N=len(AllGenesQuadrant4.index),n=len(totalmetabolic),
                 M=len((CommonVSCoefVar.index)))

# %% [markdown]
# ## Extracting metabolic VS and CV from development and tissue dataset

# %%
MetabolicClasses=pd.read_csv("/data/nandas/MetabolicClasses_August_SN_090221.csv",index_col=0)

# %%
CommonVS
# Out:
#                 Variation Score  Bin  DevelopmentBin
# WormBaseID
# WBGene00011985         0.054513    2               2
# WBGene00008485         0.485177    3               3
# WBGene00016134         0.006843    2               2
# WBGene00000950         0.013586    2               2
# WBGene00044029         0.202503    3               3
# ...                         ...  ...             ...
# WBGene00011807         0.000000    1               1
# WBGene00022802         0.275850    3               3
# WBGene00004503         0.015066    2               2
# WBGene00022018         0.426845    3               3
# WBGene00006955         0.527253    3               3
#
# [14556 rows x 3 columns]

# %%
MetabolicVS=list(set(CommonVSCoefVar.index).intersection(set(MetabolicClasses.index)))
MetabolicVS=MetabolicClasses.loc[MetabolicVS]

# %%
MetabolicVS ['Variation Score']=CommonVS ['Variation Score']
MetabolicVS ['DevelopmentBin']= CommonVS ['DevelopmentBin']

# %%
MetabolicCoefVar=list(set(CommonCoefVar.index).intersection(set(MetabolicClasses.index)))
MetabolicCoefVar=MetabolicClasses.loc[MetabolicCoefVar]

# %%
MetabolicCoefVar ['CoefVar']=CommonCoefVar.CoefVar
MetabolicCoefVar['TissueBin']=CommonCoefVar['TissueBin']

# %%
MetabolicVS
# Out:
#                Sequence Name Class  \
# Gene Name
# WBGene00003477      H28G03.6     C
# WBGene00008485       F01D4.1     A
# WBGene00006418       B0222.4     A
# WBGene00020950      W02F12.5     A
# WBGene00000212       ZK455.4     A
# ...                      ...   ...
# WBGene00014054       ZK669.4     A
# WBGene00008410       D2023.6     C
# WBGene00006566       ZK829.6     B
# WBGene00012815      Y43F8B.4     A
# WBGene00020006       R11E3.4     A
#
#                                           Molecular Function  \
# Gene Name
# WBGene00003477                             lipid phosphatase
# WBGene00008485                  UDP-glucuronosyl transferase
# WBGene00006418                 sphingosine-1-phosphate lyase
# WBGene00020950        dihydrolipoamide S-succinyltransferase
# WBGene00000212                         Acid sphingomyelinase
# ...                                                      ...
# WBGene00014054  DIHYDROLIPOAMIDE BRANCHED CHAIN TRANSACYLASE
# WBGene00008410                       Ubiquinone biosynthesis
# WBGene00006566                 tRNA-guanine transglycosylase
# WBGene00012815                 collagen prolyl 4-hydroxylase
# WBGene00020006                                           NaN
#
#                                      iCEL1273 description / Notes  \
# Gene Name
# WBGene00003477                                                NaN
# WBGene00008485  Pentose and glucuronate interconversions; Porp...
# WBGene00006418                            Sphingolipid metabolism
# WBGene00020950      Citrate cycle (TCA cycle); Lysine degradation
# WBGene00000212                            Sphingolipid metabolism
# ...                                                           ...
# WBGene00014054  Propanoate metabolism; Valine, leucine and iso...
# WBGene00008410          paralog to coq-8, ubiquinone biosynthesis
# WBGene00006566                                                NaN
# WBGene00012815  Arginine and proline metabolism; Collagen bios...
# WBGene00020006                                                NaN
#
#                                         Wormbase Description Text  \
# Gene Name
# WBGene00003477  mtm-5 encodes a catalytically inactive myotubu...
# WBGene00008485  ugt-43 is an ortholog of human UGT3A2 (UDP gly...
# WBGene00006418  tag-38 is an ortholog of human SGPL1 (sphingos...
# WBGene00020950  dlst-1 is an ortholog of human DLST (dihydroli...
# WBGene00000212  asm-2 encodes a protein similar to human acid ...
# ...                                                           ...
# WBGene00014054  ZK669.4 is orthologous to the human gene DIHYD...
# WBGene00008410  D2023.6 is orthologous to a set of uncharacter...
# WBGene00006566  tgt-1 encodes a tRNA-guanine transglycosylase ...
# WBGene00012815  phy-4.1 encodes a polypeptide that show sequen...
# WBGene00020006                                                NaN
#
#                 Variation Score  DevelopmentBin
# Gene Name
# WBGene00003477         0.012970               2
# WBGene00008485         0.485177               3
# WBGene00006418         0.081883               2
# WBGene00020950         0.000000               1
# WBGene00000212         0.067848               2
# ...                         ...             ...
# WBGene00014054         0.005625               2
# WBGene00008410         0.084869               2
# WBGene00006566         0.006686               2
# WBGene00012815         0.359814               3
# WBGene00020006         0.135095               2
#
# [2183 rows x 7 columns]

# %%
for gene in MetabolicCoefVar.index:
    CV=MetabolicCoefVar.loc[gene]['TissueBin']
    VS=MetabolicVS.loc[gene]['DevelopmentBin']
    if VS=='Highly variant' and CV=='Highly variant':
        MetabolicCoefVar.at[gene,'Quadrant']=4
    elif VS=='Highly variant' and CV!='Highly variant':
        MetabolicCoefVar.at[gene,'Quadrant']=2
    elif VS!='Highly variant' and CV=='Highly variant':
        MetabolicCoefVar.at[gene,'Quadrant']=3
    else:
        MetabolicCoefVar.at[gene,'Quadrant']=1

# %%
# MetabolicCoefVar ['TissueBin']=CoefVar['Tissue bin']

# %%
MetabolicCoefVar
# Out:
#                Sequence Name Class  \
# Gene Name
# WBGene00003477      H28G03.6     C
# WBGene00008485       F01D4.1     A
# WBGene00006418       B0222.4     A
# WBGene00020950      W02F12.5     A
# WBGene00000212       ZK455.4     A
# ...                      ...   ...
# WBGene00014054       ZK669.4     A
# WBGene00008410       D2023.6     C
# WBGene00006566       ZK829.6     B
# WBGene00012815      Y43F8B.4     A
# WBGene00020006       R11E3.4     A
#
#                                           Molecular Function  \
# Gene Name
# WBGene00003477                             lipid phosphatase
# WBGene00008485                  UDP-glucuronosyl transferase
# WBGene00006418                 sphingosine-1-phosphate lyase
# WBGene00020950        dihydrolipoamide S-succinyltransferase
# WBGene00000212                         Acid sphingomyelinase
# ...                                                      ...
# WBGene00014054  DIHYDROLIPOAMIDE BRANCHED CHAIN TRANSACYLASE
# WBGene00008410                       Ubiquinone biosynthesis
# WBGene00006566                 tRNA-guanine transglycosylase
# WBGene00012815                 collagen prolyl 4-hydroxylase
# WBGene00020006                                           NaN
#
#                                      iCEL1273 description / Notes  \
# Gene Name
# WBGene00003477                                                NaN
# WBGene00008485  Pentose and glucuronate interconversions; Porp...
# WBGene00006418                            Sphingolipid metabolism
# WBGene00020950      Citrate cycle (TCA cycle); Lysine degradation
# WBGene00000212                            Sphingolipid metabolism
# ...                                                           ...
# WBGene00014054  Propanoate metabolism; Valine, leucine and iso...
# WBGene00008410          paralog to coq-8, ubiquinone biosynthesis
# WBGene00006566                                                NaN
# WBGene00012815  Arginine and proline metabolism; Collagen bios...
# WBGene00020006                                                NaN
#
#                                         Wormbase Description Text   CoefVar  \
# Gene Name
# WBGene00003477  mtm-5 encodes a catalytically inactive myotubu...  0.862214
# WBGene00008485  ugt-43 is an ortholog of human UGT3A2 (UDP gly...  2.424174
# WBGene00006418  tag-38 is an ortholog of human SGPL1 (sphingos...  1.510227
# WBGene00020950  dlst-1 is an ortholog of human DLST (dihydroli...  0.529972
# WBGene00000212  asm-2 encodes a protein similar to human acid ...  2.386914
# ...                                                           ...       ...
# WBGene00014054  ZK669.4 is orthologous to the human gene DIHYD...  0.501306
# WBGene00008410  D2023.6 is orthologous to a set of uncharacter...  1.438169
# WBGene00006566  tgt-1 encodes a tRNA-guanine transglycosylase ...  0.477919
# WBGene00012815  phy-4.1 encodes a polypeptide that show sequen...  2.275733
# WBGene00020006                                                NaN  0.659460
#
#                          TissueBin  Quadrant
# Gene Name
# WBGene00003477      Highly variant       3.0
# WBGene00008485      Highly variant       3.0
# WBGene00006418      Highly variant       3.0
# WBGene00020950  Moderately variant       1.0
# WBGene00000212      Highly variant       3.0
# ...                            ...       ...
# WBGene00014054  Moderately variant       1.0
# WBGene00008410      Highly variant       3.0
# WBGene00006566  Moderately variant       1.0
# WBGene00012815      Highly variant       3.0
# WBGene00020006  Moderately variant       1.0
#
# [2183 rows x 8 columns]

# %%
Lowlyexpressed=MetabolicCoefVar[MetabolicCoefVar.TissueBin=='Lowly expressed']

# %%
# MetabolicCoefVar.TissueBin)

# %%
# MetabolicCoefVar['TissueBin']=CoefVar['Bin']

# %%
MetabolicCoefVar
# Out:
#                Sequence Name Class  \
# Gene Name
# WBGene00003477      H28G03.6     C
# WBGene00008485       F01D4.1     A
# WBGene00006418       B0222.4     A
# WBGene00020950      W02F12.5     A
# WBGene00000212       ZK455.4     A
# ...                      ...   ...
# WBGene00014054       ZK669.4     A
# WBGene00008410       D2023.6     C
# WBGene00006566       ZK829.6     B
# WBGene00012815      Y43F8B.4     A
# WBGene00020006       R11E3.4     A
#
#                                           Molecular Function  \
# Gene Name
# WBGene00003477                             lipid phosphatase
# WBGene00008485                  UDP-glucuronosyl transferase
# WBGene00006418                 sphingosine-1-phosphate lyase
# WBGene00020950        dihydrolipoamide S-succinyltransferase
# WBGene00000212                         Acid sphingomyelinase
# ...                                                      ...
# WBGene00014054  DIHYDROLIPOAMIDE BRANCHED CHAIN TRANSACYLASE
# WBGene00008410                       Ubiquinone biosynthesis
# WBGene00006566                 tRNA-guanine transglycosylase
# WBGene00012815                 collagen prolyl 4-hydroxylase
# WBGene00020006                                           NaN
#
#                                      iCEL1273 description / Notes  \
# Gene Name
# WBGene00003477                                                NaN
# WBGene00008485  Pentose and glucuronate interconversions; Porp...
# WBGene00006418                            Sphingolipid metabolism
# WBGene00020950      Citrate cycle (TCA cycle); Lysine degradation
# WBGene00000212                            Sphingolipid metabolism
# ...                                                           ...
# WBGene00014054  Propanoate metabolism; Valine, leucine and iso...
# WBGene00008410          paralog to coq-8, ubiquinone biosynthesis
# WBGene00006566                                                NaN
# WBGene00012815  Arginine and proline metabolism; Collagen bios...
# WBGene00020006                                                NaN
#
#                                         Wormbase Description Text   CoefVar  \
# Gene Name
# WBGene00003477  mtm-5 encodes a catalytically inactive myotubu...  0.862214
# WBGene00008485  ugt-43 is an ortholog of human UGT3A2 (UDP gly...  2.424174
# WBGene00006418  tag-38 is an ortholog of human SGPL1 (sphingos...  1.510227
# WBGene00020950  dlst-1 is an ortholog of human DLST (dihydroli...  0.529972
# WBGene00000212  asm-2 encodes a protein similar to human acid ...  2.386914
# ...                                                           ...       ...
# WBGene00014054  ZK669.4 is orthologous to the human gene DIHYD...  0.501306
# WBGene00008410  D2023.6 is orthologous to a set of uncharacter...  1.438169
# WBGene00006566  tgt-1 encodes a tRNA-guanine transglycosylase ...  0.477919
# WBGene00012815  phy-4.1 encodes a polypeptide that show sequen...  2.275733
# WBGene00020006                                                NaN  0.659460
#
#                          TissueBin  Quadrant
# Gene Name
# WBGene00003477      Highly variant       3.0
# WBGene00008485      Highly variant       3.0
# WBGene00006418      Highly variant       3.0
# WBGene00020950  Moderately variant       1.0
# WBGene00000212      Highly variant       3.0
# ...                            ...       ...
# WBGene00014054  Moderately variant       1.0
# WBGene00008410      Highly variant       3.0
# WBGene00006566  Moderately variant       1.0
# WBGene00012815      Highly variant       3.0
# WBGene00020006  Moderately variant       1.0
#
# [2183 rows x 8 columns]

# %%
for index in MetabolicCoefVar.index:
    if index in Lowlyexpressed.index:
        MetabolicCoefVar.at[index,'TissueBin']="Lowlyexpressed"

# %%
MetabolicCoefVar['VS']=MetabolicVS['Variation Score']

# %%
MetabolicCoefVar['DevelopmentBin']=MetabolicVS['DevelopmentBin']

# %%
MetabolicCoefVar
# Out:
#                Sequence Name Class  \
# Gene Name
# WBGene00003477      H28G03.6     C
# WBGene00008485       F01D4.1     A
# WBGene00006418       B0222.4     A
# WBGene00020950      W02F12.5     A
# WBGene00000212       ZK455.4     A
# ...                      ...   ...
# WBGene00014054       ZK669.4     A
# WBGene00008410       D2023.6     C
# WBGene00006566       ZK829.6     B
# WBGene00012815      Y43F8B.4     A
# WBGene00020006       R11E3.4     A
#
#                                           Molecular Function  \
# Gene Name
# WBGene00003477                             lipid phosphatase
# WBGene00008485                  UDP-glucuronosyl transferase
# WBGene00006418                 sphingosine-1-phosphate lyase
# WBGene00020950        dihydrolipoamide S-succinyltransferase
# WBGene00000212                         Acid sphingomyelinase
# ...                                                      ...
# WBGene00014054  DIHYDROLIPOAMIDE BRANCHED CHAIN TRANSACYLASE
# WBGene00008410                       Ubiquinone biosynthesis
# WBGene00006566                 tRNA-guanine transglycosylase
# WBGene00012815                 collagen prolyl 4-hydroxylase
# WBGene00020006                                           NaN
#
#                                      iCEL1273 description / Notes  \
# Gene Name
# WBGene00003477                                                NaN
# WBGene00008485  Pentose and glucuronate interconversions; Porp...
# WBGene00006418                            Sphingolipid metabolism
# WBGene00020950      Citrate cycle (TCA cycle); Lysine degradation
# WBGene00000212                            Sphingolipid metabolism
# ...                                                           ...
# WBGene00014054  Propanoate metabolism; Valine, leucine and iso...
# WBGene00008410          paralog to coq-8, ubiquinone biosynthesis
# WBGene00006566                                                NaN
# WBGene00012815  Arginine and proline metabolism; Collagen bios...
# WBGene00020006                                                NaN
#
#                                         Wormbase Description Text   CoefVar  \
# Gene Name
# WBGene00003477  mtm-5 encodes a catalytically inactive myotubu...  0.862214
# WBGene00008485  ugt-43 is an ortholog of human UGT3A2 (UDP gly...  2.424174
# WBGene00006418  tag-38 is an ortholog of human SGPL1 (sphingos...  1.510227
# WBGene00020950  dlst-1 is an ortholog of human DLST (dihydroli...  0.529972
# WBGene00000212  asm-2 encodes a protein similar to human acid ...  2.386914
# ...                                                           ...       ...
# WBGene00014054  ZK669.4 is orthologous to the human gene DIHYD...  0.501306
# WBGene00008410  D2023.6 is orthologous to a set of uncharacter...  1.438169
# WBGene00006566  tgt-1 encodes a tRNA-guanine transglycosylase ...  0.477919
# WBGene00012815  phy-4.1 encodes a polypeptide that show sequen...  2.275733
# WBGene00020006                                                NaN  0.659460
#
#                          TissueBin  Quadrant        VS  DevelopmentBin
# Gene Name
# WBGene00003477      Highly variant       3.0  0.012970               2
# WBGene00008485      Highly variant       3.0  0.485177               3
# WBGene00006418      Highly variant       3.0  0.081883               2
# WBGene00020950  Moderately variant       1.0  0.000000               1
# WBGene00000212      Highly variant       3.0  0.067848               2
# ...                            ...       ...       ...             ...
# WBGene00014054  Moderately variant       1.0  0.005625               2
# WBGene00008410      Highly variant       3.0  0.084869               2
# WBGene00006566  Moderately variant       1.0  0.006686               2
# WBGene00012815      Highly variant       3.0  0.359814               3
# WBGene00020006  Moderately variant       1.0  0.135095               2
#
# [2183 rows x 10 columns]

# %% [markdown]
# ## Dividing metabolic genes into quadrants

# %%
## Common lowly expressed

# %%
LowExpKim
# Out:
#                 DH2_N2_0  DH2_N2_2  DH2_N2_4  DH2_N2_6  DH2_N2_8  DH2_N2_10  \
# WormBaseID
# WBGene00012335  1.012198  1.489701  0.738886  0.629337  0.171848   0.097373
# WBGene00005169  0.303189  0.364411  0.484143  0.659780  0.360321   0.204166
# WBGene00005565  0.257818       NaN  0.082339  0.224419  0.076600        NaN
# WBGene00001667  0.507856  0.627847  0.681209  0.618892  0.482845   0.444585
# WBGene00018443  0.059516  0.490518  0.114045  0.103612  0.070731   0.040078
# ...                  ...       ...       ...       ...       ...        ...
# WBGene00007727       NaN  0.054514  0.135194  0.046060       NaN        NaN
# WBGene00044284  0.280497  0.192650  0.477768       NaN       NaN        NaN
# WBGene00005081  1.653349  0.879133  0.579125  0.417822  0.380304   0.395063
# WBGene00019553       NaN  0.957339  0.118709  0.161774       NaN   0.125151
# WBGene00015121       NaN  0.832246  1.031978       NaN       NaN   0.181330
#
#                 DH2_N2_12  DH2_N2_14  DH2_N2_16  DH2_N2_18  ...  DH2_N2_32  \
# WormBaseID                                                  ...
# WBGene00012335   0.098352   0.228040   0.179612        NaN  ...        NaN
# WBGene00005169   0.206219   0.159381   0.062767        NaN  ...   0.080979
# WBGene00005565        NaN        NaN        NaN        NaN  ...        NaN
# WBGene00001667   0.656312   0.480547   1.324733   0.544404  ...   0.461189
# WBGene00018443   0.080962        NaN   0.147854        NaN  ...        NaN
# ...                   ...        ...        ...        ...  ...        ...
# WBGene00007727   0.071982   0.041724        NaN        NaN  ...        NaN
# WBGene00044284        NaN        NaN   0.232276        NaN  ...   0.249727
# WBGene00005081   0.253932   0.336439   0.132496   0.142930  ...   0.085470
# WBGene00019553   0.252819        NaN        NaN   0.249032  ...        NaN
# WBGene00015121        NaN        NaN        NaN        NaN  ...        NaN
#
#                 DH2_N2_34  DH2_N2_36  DH2_N2_38  DH5_N2_38  DH5_N2_40  \
# WormBaseID
# WBGene00012335   0.084695   0.065306        NaN        NaN        NaN
# WBGene00005169   0.147987   0.136929   0.161941   0.213330   0.188588
# WBGene00005565        NaN        NaN        NaN        NaN        NaN
# WBGene00001667   0.446195   0.435791        NaN   0.428805   0.379073
# WBGene00018443        NaN   0.026879        NaN   0.031407        NaN
# ...                   ...        ...        ...        ...        ...
# WBGene00007727        NaN        NaN        NaN        NaN        NaN
# WBGene00044284        NaN        NaN        NaN        NaN        NaN
# WBGene00005081   0.187433   0.120436   0.170921   0.140725   0.099523
# WBGene00019553        NaN        NaN        NaN        NaN        NaN
# WBGene00015121        NaN        NaN        NaN   0.142101        NaN
#
#                 DH5_N2_42  DH5_N2_44  DH5_N2_46  DH5_N2_48
# WormBaseID
# WBGene00012335        NaN        NaN        NaN        NaN
# WBGene00005169   0.056753   0.057094   0.056694   0.023326
# WBGene00005565        NaN        NaN        NaN        NaN
# WBGene00001667   0.399269   0.487741   0.256407   0.164103
# WBGene00018443        NaN        NaN   0.033387        NaN
# ...                   ...        ...        ...        ...
# WBGene00007727        NaN   0.029893   0.178104   0.195409
# WBGene00044284   0.210021   0.105642        NaN        NaN
# WBGene00005081   0.119801   0.210911   0.179515   0.295435
# WBGene00019553   0.104366        NaN        NaN        NaN
# WBGene00015121   0.151215        NaN        NaN        NaN
#
# [3552 rows x 26 columns]

# %%
MetabolicLowExpKim=list(set(MetabolicClasses.index).intersection(set(LowExpKim.index)))

#  'WBGene00012108',
#  'WBGene00044044',
#  'WBGene00015872',
#  'WBGene00022808',
#  'WBGene00009610',
#  'WBGene00021553',
#  'WBGene00007364',
#  'WBGene00000372',
#  'WBGene00001839',
#  'WBGene00001641',
#  'WBGene00007470',
#  'WBGene00022512',
#  'WBGene00015071',
#  'WBGene00018141',
#  'WBGene00017233',
#  'WBGene00007473',
#  'WBGene00008809',
#  'WBGene00001642',
#  'WBGene00022377',
#  'WBGene00011161',
#  'WBGene00008786',
#  'WBGene00077688',
#  'WBGene00011654',
#  'WBGene00010380',
#  'WBGene00013226',
#  'WBGene00044286',
#  'WBGene00014162',
#  'WBGene00011675',
#  'WBGene00019675',
#  'WBGene00022498',
#  'WBGene00008077',
#  'WBGene00001532',
#  'WBGene00008475',
#  'WBGene00010915',
#  'WBGene00001640',
#  'WBGene00003176',
#  'WBGene00011929',
#  'WBGene00003098',
#  'WBGene00015338',
#  'WBGene00012394',
#  'WBGene00020154',
#  'WBGene00008478',
#  'WBGene00011046',
#  'WBGene00001765',
#  'WBGene00012914',
#  'WBGene00044362',
#  'WBGene00017366',
#  'WBGene00007471',
#  'WBGene00015773',
#  'WBGene00021164',
#  'WBGene00044088',
#  'WBGene00008160',
#  'WBGene00018142',
#  'WBGene00015982',
#  'WBGene00011960',
#  'WBGene00020875',
#  'WBGene00008785',
#  'WBGene00022267',
#  'WBGene00010120',
#  'WBGene00015775',
#  'WBGene00015873',
#  'WBGene00019851',
#  'WBGene00008293',
#  'WBGene00011170',
#  'WBGene00011519',
#  'WBGene00018754',
#  'WBGene00010589',
#  'WBGene00019668',
#  'WBGene00009032',
#  'WBGene00007211',
#  'WBGene00019233',
#  'WBGene00011659',
#  'WBGene00010067',
#  'WBGene00011847',
#  'WBGene00014128',
#  'WBGene00013450',
#  'WBGene00007140',
#  'WBGene00014236',
#  'WBGene00019690',
#  'WBGene00021710',
#  'WBGene00007466',
#  'WBGene00000108',
#  'WBGene00009607',
#  'WBGene00022809',
#  'WBGene00008162',
#  'WBGene00020797',
#  'WBGene00013049',
#  'WBGene00003906']

# %%
MetabolicCoefVar['DevelopmentBin']
# Out:
# Gene Name
# WBGene00003477    2
# WBGene00008485    3
# WBGene00006418    2
# WBGene00020950    1
# WBGene00000212    2
#                  ..
# WBGene00014054    2
# WBGene00008410    2
# WBGene00006566    2
# WBGene00012815    3
# WBGene00020006    2
# Name: DevelopmentBin, Length: 2183, dtype: int64

# %%
MetabolicLowExpKim
# Out:
# ['WBGene00008471',
#  'WBGene00007361',
#  'WBGene00012049',
#  'WBGene00018264',
#  'WBGene00011653',
#  'WBGene00007954',
#  'WBGene00009615',
#  'WBGene00010392',
#  'WBGene00019471',
#  'WBGene00010775',
#  'WBGene00020474',
#  'WBGene00007829',
#  'WBGene00015406',
#  'WBGene00010391',
#  'WBGene00007291',
#  'WBGene00044003',
#  'WBGene00020631',
#  'WBGene00017723',
#  'WBGene00006435',
#  'WBGene00017061',
#  'WBGene00018771',
#  'WBGene00010694',
#  'WBGene00010606',
#  'WBGene00013873',
#  'WBGene00011675',
#  'WBGene00019675',
#  'WBGene00022498',
#  'WBGene00008077',
#  'WBGene00001532',
#  'WBGene00008475',
#  'WBGene00010915',
#  'WBGene00001640',
#  'WBGene00003176',
#  'WBGene00011929',
#  'WBGene00003098',
#  'WBGene00015338',
#  'WBGene00012394',
#  'WBGene00020154',
#  'WBGene00008478',
#  'WBGene00011046',
#  'WBGene00001765',
#  'WBGene00012914',
#  'WBGene00044362',
#  'WBGene00017366',
#  'WBGene00007471',
#  'WBGene00015773',
#  'WBGene00021164',
#  'WBGene00044088',
#  'WBGene00008160',
#  'WBGene00018142',
#  'WBGene00015982',
#  'WBGene00011960',
#  'WBGene00020875',
#  'WBGene00008785',
#  'WBGene00022267',
#  'WBGene00010120',
#  'WBGene00015775',
#  'WBGene00015873',
#  'WBGene00019851',
#  'WBGene00008293',
#  'WBGene00011170',
#  'WBGene00011519',
#  'WBGene00018754',
#  'WBGene00010589',
#  'WBGene00019668',
#  'WBGene00009032',
#  'WBGene00007211',
#  'WBGene00019233',
#  'WBGene00011659',
#  'WBGene00010067',
#  'WBGene00011847',
#  'WBGene00014128',
#  'WBGene00013450',
#  'WBGene00007140',
#  'WBGene00014236',
#  'WBGene00019690',
#  'WBGene00021710',
#  'WBGene00007466',
#  'WBGene00000108',
#  'WBGene00009607',
#  'WBGene00022809',
#  'WBGene00008162',
#  'WBGene00020797',
#  'WBGene00013049',
#  'WBGene00003906']

# %%
MetabolicCoefVar['DevelopmentBin']=str(MetabolicCoefVar['DevelopmentBin'])

# %%
MetabolicCoefVar
# Out:
#                Sequence Name Class  \
# Gene Name
# WBGene00003477      H28G03.6     C
# WBGene00008485       F01D4.1     A
# WBGene00006418       B0222.4     A
# WBGene00020950      W02F12.5     A
# WBGene00000212       ZK455.4     A
# ...                      ...   ...
# WBGene00014054       ZK669.4     A
# WBGene00008410       D2023.6     C
# WBGene00006566       ZK829.6     B
# WBGene00012815      Y43F8B.4     A
# WBGene00020006       R11E3.4     A
#
#                                           Molecular Function  \
# Gene Name
# WBGene00003477                             lipid phosphatase
# WBGene00008485                  UDP-glucuronosyl transferase
# WBGene00006418                 sphingosine-1-phosphate lyase
# WBGene00020950        dihydrolipoamide S-succinyltransferase
# WBGene00000212                         Acid sphingomyelinase
# ...                                                      ...
# WBGene00014054  DIHYDROLIPOAMIDE BRANCHED CHAIN TRANSACYLASE
# WBGene00008410                       Ubiquinone biosynthesis
# WBGene00006566                 tRNA-guanine transglycosylase
# WBGene00012815                 collagen prolyl 4-hydroxylase
# WBGene00020006                                           NaN
#
#                                      iCEL1273 description / Notes  \
# Gene Name
# WBGene00003477                                                NaN
# WBGene00008485  Pentose and glucuronate interconversions; Porp...
# WBGene00006418                            Sphingolipid metabolism
# WBGene00020950      Citrate cycle (TCA cycle); Lysine degradation
# WBGene00000212                            Sphingolipid metabolism
# ...                                                           ...
# WBGene00014054  Propanoate metabolism; Valine, leucine and iso...
# WBGene00008410          paralog to coq-8, ubiquinone biosynthesis
# WBGene00006566                                                NaN
# WBGene00012815  Arginine and proline metabolism; Collagen bios...
# WBGene00020006                                                NaN
#
#                                         Wormbase Description Text   CoefVar  \
# Gene Name
# WBGene00003477  mtm-5 encodes a catalytically inactive myotubu...  0.862214
# WBGene00008485  ugt-43 is an ortholog of human UGT3A2 (UDP gly...  2.424174
# WBGene00006418  tag-38 is an ortholog of human SGPL1 (sphingos...  1.510227
# WBGene00020950  dlst-1 is an ortholog of human DLST (dihydroli...  0.529972
# WBGene00000212  asm-2 encodes a protein similar to human acid ...  2.386914
# ...                                                           ...       ...
# WBGene00014054  ZK669.4 is orthologous to the human gene DIHYD...  0.501306
# WBGene00008410  D2023.6 is orthologous to a set of uncharacter...  1.438169
# WBGene00006566  tgt-1 encodes a tRNA-guanine transglycosylase ...  0.477919
# WBGene00012815  phy-4.1 encodes a polypeptide that show sequen...  2.275733
# WBGene00020006                                                NaN  0.659460
#
#                          TissueBin  Quadrant        VS  \
# Gene Name
# WBGene00003477      Highly variant       3.0  0.012970
# WBGene00008485      Highly variant       3.0  0.485177
# WBGene00006418      Highly variant       3.0  0.081883
# WBGene00020950  Moderately variant       1.0  0.000000
# WBGene00000212      Highly variant       3.0  0.067848
# ...                            ...       ...       ...
# WBGene00014054  Moderately variant       1.0  0.005625
# WBGene00008410      Highly variant       3.0  0.084869
# WBGene00006566  Moderately variant       1.0  0.006686
# WBGene00012815      Highly variant       3.0  0.359814
# WBGene00020006  Moderately variant       1.0  0.135095
#
#                                                    DevelopmentBin
# Gene Name
# WBGene00003477  Gene Name\nWBGene00003477    2\nWBGene00008485...
# WBGene00008485  Gene Name\nWBGene00003477    2\nWBGene00008485...
# WBGene00006418  Gene Name\nWBGene00003477    2\nWBGene00008485...
# WBGene00020950  Gene Name\nWBGene00003477    2\nWBGene00008485...
# WBGene00000212  Gene Name\nWBGene00003477    2\nWBGene00008485...
# ...                                                           ...
# WBGene00014054  Gene Name\nWBGene00003477    2\nWBGene00008485...
# WBGene00008410  Gene Name\nWBGene00003477    2\nWBGene00008485...
# WBGene00006566  Gene Name\nWBGene00003477    2\nWBGene00008485...
# WBGene00012815  Gene Name\nWBGene00003477    2\nWBGene00008485...
# WBGene00020006  Gene Name\nWBGene00003477    2\nWBGene00008485...
#
# [2183 rows x 10 columns]

# %%
# (MetabolicCoefVar.loc[genes,'DevelopmentBin'])==2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WBGene00006955'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-f5a3d204f8b0> in <module>
# ----> 1 (MetabolicCoefVar.loc[genes,'DevelopmentBin'])==2
#
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     784                 # We don't need to check for tuples here because those are
#     785                 #  caught by the _is_nested_tuple_indexer check above.
# --> 786                 section = self._getitem_axis(key, axis=i)
#     787
#     788                 # We should never have a scalar section here, because
#
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3480             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3481         else:
# -> 3482             loc = self.index.get_loc(key)
#    3483
#    3484             if isinstance(loc, np.ndarray):
#
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 'WBGene00006955'

# %%
# MetabolicCoefVar['DevelopmentBin']=str(MetabolicCoefVar['DevelopmentBin'])
for genes in MetabolicCoefVar.index:
    print(genes)
    if genes in MetabolicLowExpKim:
        print(genes)
        MetabolicCoefVar.at[genes,'Development Bin']='Lowlyexpressed'
        print(MetabolicCoefVar.loc[genes,'Development Bin'])
    elif (MetabolicCoefVar.loc[genes,'DevelopmentBin'])==1:
        MetabolicCoefVar.at[genes,'Development Bin']='Invariant'
    elif (MetabolicCoefVar.loc[genes,'DevelopmentBin'])==3:
        MetabolicCoefVar.at[genes,'Development Bin']='Highly variant'
    elif (MetabolicCoefVar.loc[genes,'DevelopmentBin'])==2:
        MetabolicCoefVar.at[genes,'Development Bin']='Moderately variant'
# Out:
# WBGene00003477
# WBGene00008485
# WBGene00006418
# WBGene00020950
# WBGene00000212
# WBGene00016603
# WBGene00003091
# WBGene00006946
# WBGene00008336
# WBGene00022663
# WBGene00001633
# WBGene00008499
# WBGene00009271
# WBGene00010411
# WBGene00017719
# WBGene00007089
# WBGene00000207
# WBGene00011631
# WBGene00011321
# WBGene00006915
# WBGene00011559
# WBGene00007836
# WBGene00012166
# WBGene00022770
# WBGene00004893
# WBGene00020139
# WBGene00018657
# WBGene00016863
# WBGene00006910
# WBGene00010197
# WBGene00019246
# WBGene00001405
# WBGene00003095
# WBGene00007533
# WBGene00002029
# WBGene00015509
# WBGene00001336
# WBGene00004257
# WBGene00000210
# WBGene00015861
# WBGene00013904
# WBGene00001553
# WBGene00019937
# WBGene00013807
# WBGene00013103
# WBGene00012007
# WBGene00011232
# WBGene00001177
# WBGene00001073
# WBGene00020151
# WBGene00019682
# WBGene00001246
# WBGene00017775
# WBGene00019229
# WBGene00018408
# WBGene00020419
# WBGene00019473
# WBGene00008408
# WBGene00021314
# WBGene00000254
# WBGene00014148
# WBGene00017565
# WBGene00019516
# WBGene00000913
# WBGene00011004
# WBGene00008290
# WBGene00011543
# WBGene00017283
# WBGene00012777
# WBGene00007036
# WBGene00021430
# WBGene00000974
# WBGene00008117
# WBGene00013312
# WBGene00011587
# WBGene00021167
# WBGene00000985
# WBGene00010286
# WBGene00020036
# WBGene00012142
# WBGene00020962
# WBGene00016507
# WBGene00003844
# WBGene00013308
# WBGene00009882
# WBGene00019489
# WBGene00008409
# WBGene00006510
# WBGene00020823
# WBGene00019654
# WBGene00009849
# WBGene00019236
# WBGene00006936
# WBGene00012376
# WBGene00020166
# WBGene00017272
# WBGene00003773
# WBGene00022582
# WBGene00017340
# WBGene00014160
# WBGene00015965
# WBGene00000983
# WBGene00008735
# WBGene00020557
# WBGene00011089
# WBGene00020594
# WBGene00011271
# WBGene00011564
# WBGene00013804
# WBGene00003099
# WBGene00003966
# WBGene00010706
# WBGene00013379
# WBGene00016786
# WBGene00000831
# WBGene00021407
# WBGene00009543
# WBGene00011350
# WBGene00021849
# WBGene00000213
# WBGene00004049
# WBGene00022832
# WBGene00014054
# WBGene00008410
# WBGene00006566
# WBGene00012815
# WBGene00020006

# %%
MetabolicCoefVar
# Out:
#                Sequence Name Class  \
# Gene Name
# WBGene00003477      H28G03.6     C
# WBGene00008485       F01D4.1     A
# WBGene00006418       B0222.4     A
# WBGene00020950      W02F12.5     A
# WBGene00000212       ZK455.4     A
# ...                      ...   ...
# WBGene00014054       ZK669.4     A
# WBGene00008410       D2023.6     C
# WBGene00006566       ZK829.6     B
# WBGene00012815      Y43F8B.4     A
# WBGene00020006       R11E3.4     A
#
#                                           Molecular Function  \
# Gene Name
# WBGene00003477                             lipid phosphatase
# WBGene00008485                  UDP-glucuronosyl transferase
# WBGene00006418                 sphingosine-1-phosphate lyase
# WBGene00020950        dihydrolipoamide S-succinyltransferase
# WBGene00000212                         Acid sphingomyelinase
# ...                                                      ...
# WBGene00014054  DIHYDROLIPOAMIDE BRANCHED CHAIN TRANSACYLASE
# WBGene00008410                       Ubiquinone biosynthesis
# WBGene00006566                 tRNA-guanine transglycosylase
# WBGene00012815                 collagen prolyl 4-hydroxylase
# WBGene00020006                                           NaN
#
#                                      iCEL1273 description / Notes  \
# Gene Name
# WBGene00003477                                                NaN
# WBGene00008485  Pentose and glucuronate interconversions; Porp...
# WBGene00006418                            Sphingolipid metabolism
# WBGene00020950      Citrate cycle (TCA cycle); Lysine degradation
# WBGene00000212                            Sphingolipid metabolism
# ...                                                           ...
# WBGene00014054  Propanoate metabolism; Valine, leucine and iso...
# WBGene00008410          paralog to coq-8, ubiquinone biosynthesis
# WBGene00006566                                                NaN
# WBGene00012815  Arginine and proline metabolism; Collagen bios...
# WBGene00020006                                                NaN
#
#                                         Wormbase Description Text   CoefVar  \
# Gene Name
# WBGene00003477  mtm-5 encodes a catalytically inactive myotubu...  0.862214
# WBGene00008485  ugt-43 is an ortholog of human UGT3A2 (UDP gly...  2.424174
# WBGene00006418  tag-38 is an ortholog of human SGPL1 (sphingos...  1.510227
# WBGene00020950  dlst-1 is an ortholog of human DLST (dihydroli...  0.529972
# WBGene00000212  asm-2 encodes a protein similar to human acid ...  2.386914
# ...                                                           ...       ...
# WBGene00014054  ZK669.4 is orthologous to the human gene DIHYD...  0.501306
# WBGene00008410  D2023.6 is orthologous to a set of uncharacter...  1.438169
# WBGene00006566  tgt-1 encodes a tRNA-guanine transglycosylase ...  0.477919
# WBGene00012815  phy-4.1 encodes a polypeptide that show sequen...  2.275733
# WBGene00020006                                                NaN  0.659460
#
#                          TissueBin  Quadrant        VS  DevelopmentBin  \
# Gene Name
# WBGene00003477      Highly variant       3.0  0.012970               2
# WBGene00008485      Highly variant       3.0  0.485177               3
# WBGene00006418      Highly variant       3.0  0.081883               2
# WBGene00020950  Moderately variant       1.0  0.000000               1
# WBGene00000212      Highly variant       3.0  0.067848               2
# ...                            ...       ...       ...             ...
# WBGene00014054  Moderately variant       1.0  0.005625               2
# WBGene00008410      Highly variant       3.0  0.084869               2
# WBGene00006566  Moderately variant       1.0  0.006686               2
# WBGene00012815      Highly variant       3.0  0.359814               3
# WBGene00020006  Moderately variant       1.0  0.135095               2
#
#                    Development Bin
# Gene Name
# WBGene00003477  Moderately variant
# WBGene00008485      Highly variant
# WBGene00006418  Moderately variant
# WBGene00020950           Invariant
# WBGene00000212  Moderately variant
# ...                            ...
# WBGene00014054  Moderately variant
# WBGene00008410  Moderately variant
# WBGene00006566  Moderately variant
# WBGene00012815      Highly variant
# WBGene00020006  Moderately variant
#
# [2183 rows x 11 columns]

# %%
MetabolicCoefVar.drop(columns=['DevelopmentBin'],inplace=True)

# %%
MetabolicCoefVar.columns
# Out:
# Index(['Sequence Name', 'Class', 'Molecular Function',
#        'iCEL1273 description / Notes', 'Wormbase Description Text', 'CoefVar',
#        'TissueBin', 'Quadrant', 'VS', 'Development Bin'],
#       dtype='object')

# %% [markdown]
# ## Removing genes that are lowly expressed in both development and tissues

# %%
count=0
for genes in MetabolicCoefVar.index:
    if (MetabolicCoefVar.loc[genes,'Development Bin'])=='Lowlyexpressed' :
        if  (MetabolicCoefVar.loc[genes,'TissueBin'])=='Lowlyexpressed':
            print(genes)
            count=count+1
            print(count)
            MetabolicCoefVar.drop(index=genes,inplace=True)

# %%
MetabolicCoefVar
# Out:
#                Sequence Name Class  \
# Gene Name
# WBGene00003477      H28G03.6     C
# WBGene00008485       F01D4.1     A
# WBGene00006418       B0222.4     A
# WBGene00020950      W02F12.5     A
# WBGene00000212       ZK455.4     A
# ...                      ...   ...
# WBGene00014054       ZK669.4     A
# WBGene00008410       D2023.6     C
# WBGene00006566       ZK829.6     B
# WBGene00012815      Y43F8B.4     A
# WBGene00020006       R11E3.4     A
#
#                                           Molecular Function  \
# Gene Name
# WBGene00003477                             lipid phosphatase
# WBGene00008485                  UDP-glucuronosyl transferase
# WBGene00006418                 sphingosine-1-phosphate lyase
# WBGene00020950        dihydrolipoamide S-succinyltransferase
# WBGene00000212                         Acid sphingomyelinase
# ...                                                      ...
# WBGene00014054  DIHYDROLIPOAMIDE BRANCHED CHAIN TRANSACYLASE
# WBGene00008410                       Ubiquinone biosynthesis
# WBGene00006566                 tRNA-guanine transglycosylase
# WBGene00012815                 collagen prolyl 4-hydroxylase
# WBGene00020006                                           NaN
#
#                                      iCEL1273 description / Notes  \
# Gene Name
# WBGene00003477                                                NaN
# WBGene00008485  Pentose and glucuronate interconversions; Porp...
# WBGene00006418                            Sphingolipid metabolism
# WBGene00020950      Citrate cycle (TCA cycle); Lysine degradation
# WBGene00000212                            Sphingolipid metabolism
# ...                                                           ...
# WBGene00014054  Propanoate metabolism; Valine, leucine and iso...
# WBGene00008410          paralog to coq-8, ubiquinone biosynthesis
# WBGene00006566                                                NaN
# WBGene00012815  Arginine and proline metabolism; Collagen bios...
# WBGene00020006                                                NaN
#
#                                         Wormbase Description Text   CoefVar  \
# Gene Name
# WBGene00003477  mtm-5 encodes a catalytically inactive myotubu...  0.862214
# WBGene00008485  ugt-43 is an ortholog of human UGT3A2 (UDP gly...  2.424174
# WBGene00006418  tag-38 is an ortholog of human SGPL1 (sphingos...  1.510227
# WBGene00020950  dlst-1 is an ortholog of human DLST (dihydroli...  0.529972
# WBGene00000212  asm-2 encodes a protein similar to human acid ...  2.386914
# ...                                                           ...       ...
# WBGene00014054  ZK669.4 is orthologous to the human gene DIHYD...  0.501306
# WBGene00008410  D2023.6 is orthologous to a set of uncharacter...  1.438169
# WBGene00006566  tgt-1 encodes a tRNA-guanine transglycosylase ...  0.477919
# WBGene00012815  phy-4.1 encodes a polypeptide that show sequen...  2.275733
# WBGene00020006                                                NaN  0.659460
#
#                          TissueBin  Quadrant        VS     Development Bin
# Gene Name
# WBGene00003477      Highly variant       3.0  0.012970  Moderately variant
# WBGene00008485      Highly variant       3.0  0.485177      Highly variant
# WBGene00006418      Highly variant       3.0  0.081883  Moderately variant
# WBGene00020950  Moderately variant       1.0  0.000000           Invariant
# WBGene00000212      Highly variant       3.0  0.067848  Moderately variant
# ...                            ...       ...       ...                 ...
# WBGene00014054  Moderately variant       1.0  0.005625  Moderately variant
# WBGene00008410      Highly variant       3.0  0.084869  Moderately variant
# WBGene00006566  Moderately variant       1.0  0.006686  Moderately variant
# WBGene00012815      Highly variant       3.0  0.359814      Highly variant
# WBGene00020006  Moderately variant       1.0  0.135095  Moderately variant
#
# [2183 rows x 10 columns]

# %%
from scipy.stats import pearsonr
from scipy.stats import spearmanr
FilteredMetabolicVS=MetabolicCoefVar.dropna(inplace=False)
spearmanr((FilteredMetabolicVS['VS']),(FilteredMetabolicVS['CoefVar']))
# Out:
# SpearmanrResult(correlation=0.6217912500152445, pvalue=2.1908490931963785e-142)

# %%
pearsonr((FilteredMetabolicVS['VS']),(FilteredMetabolicVS['CoefVar']))
# Out:
# (0.4896110547751935, 1.0812936147649341e-80)

# %% [markdown]
# ## Quadrant distinction

# %%
for gene in MetabolicCoefVar.index:
    CV=MetabolicCoefVar.loc[gene]['TissueBin']
    VS=MetabolicCoefVar.loc[gene]['Development Bin']
    if VS=='Highly variant' and CV=='Highly variant':
        MetabolicCoefVar.at[gene,'Quadrant']=4
    elif VS=='Highly variant' and CV!='Highly variant':
        MetabolicCoefVar.at[gene,'Quadrant']=2
    elif VS!='Highly variant' and CV=='Highly variant':
        MetabolicCoefVar.at[gene,'Quadrant']=3
    else:
        MetabolicCoefVar.at[gene,'Quadrant']=1

# %%
# type(MetabolicCoefVar.loc['WBGene00009981']['Development Bin'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WBGene00009981'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-b6a49a600e0d> in <module>
# ----> 1 type(MetabolicCoefVar.loc['WBGene00009981']['Development Bin'])
#
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3480             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3481         else:
# -> 3482             loc = self.index.get_loc(key)
#    3483
#    3484             if isinstance(loc, np.ndarray):
#
# ~/miniconda3/envs/metabolism/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 'WBGene00009981'

# %%
FilteredMetabolicVS=(MetabolicCoefVar[['Development Bin','TissueBin']]).dropna()

# %%
FilteredMetabolicVS
# Out:
#                    Development Bin           TissueBin
# Gene Name
# WBGene00013575  Moderately variant      Highly variant
# WBGene00009512      Highly variant      Highly variant
# WBGene00008411  Moderately variant  Moderately variant
# WBGene00011006      Highly variant      Highly variant
# WBGene00021401  Moderately variant  Moderately variant
# ...                            ...                 ...
# WBGene00012363  Moderately variant  Moderately variant
# WBGene00021636  Moderately variant      Highly variant
# WBGene00022140      Highly variant      Highly variant
# WBGene00004248  Moderately variant      Highly variant
# WBGene00010060  Moderately variant      Highly variant
#
# [2183 rows x 2 columns]

# %%
# FilteredMetabolicVS=MetabolicCoefVar[MetabolicCoefVar['Development Bin']!=np.nan]
# FilteredMetabolicVS=FilteredMetabolicVS[FilteredMetabolicVS['Development Bin']!=np.NaN]
# FilteredMetabolicVS=FilteredMetabolicVS[FilteredMetabolicVS['Development Bin']!='nan']
# FilteredMetabolicVS=FilteredMetabolicVS[FilteredMetabolicVS['TissueBin']!=np.NaN]
# FilteredMetabolicVS=FilteredMetabolicVS[FilteredMetabolicVS['TissueBin']!=np.nan]
# FilteredMetabolicVS=FilteredMetabolicVS[FilteredMetabolicVS['TissueBin']!='nan']

# %%
for gene in FilteredMetabolicVS.index:
    CV=FilteredMetabolicVS.loc[gene]['TissueBin']
    VS=FilteredMetabolicVS.loc[gene]['Development Bin']
    if VS=='Highly variant' and CV=='Highly variant':
        FilteredMetabolicVS.at[gene,'Quadrant']=4
    elif VS=='Highly variant' and CV!='Highly variant':
        FilteredMetabolicVS.at[gene,'Quadrant']=2
    elif VS!='Highly variant' and CV=='Highly variant':
        FilteredMetabolicVS.at[gene,'Quadrant']=3
    else:
        FilteredMetabolicVS.at[gene,'Quadrant']=1

# %%
FilteredMetabolicVS
# Out:
#                    Development Bin           TissueBin  Quadrant
# Gene Name
# WBGene00013575  Moderately variant      Highly variant       3.0
# WBGene00009512      Highly variant      Highly variant       4.0
# WBGene00008411  Moderately variant  Moderately variant       1.0
# WBGene00011006      Highly variant      Highly variant       4.0
# WBGene00021401  Moderately variant  Moderately variant       1.0
# ...                            ...                 ...       ...
# WBGene00012363  Moderately variant  Moderately variant       1.0
# WBGene00021636  Moderately variant      Highly variant       3.0
# WBGene00022140      Highly variant      Highly variant       4.0
# WBGene00004248  Moderately variant      Highly variant       3.0
# WBGene00010060  Moderately variant      Highly variant       3.0
#
# [2183 rows x 3 columns]

# %%
Quadrant4=FilteredMetabolicVS[FilteredMetabolicVS.Quadrant==4]
Quadrant3=FilteredMetabolicVS[FilteredMetabolicVS.Quadrant==3]
Quadrant2=FilteredMetabolicVS[FilteredMetabolicVS.Quadrant==2]
Quadrant1=FilteredMetabolicVS[FilteredMetabolicVS.Quadrant==1]

# %%
Quadrant1.to_csv("Quadrant1.csv")
Quadrant2.to_csv("Quadrant2.csv")
Quadrant3.to_csv("Quadrant3.csv")
Quadrant4.to_csv("Quadrant4.csv")

# %% [markdown]
# ## Dividing only iCEL1314 genes into quadrants

# %%
ClassA=MetabolicClasses[MetabolicClasses.Class=='A']
classAQ1=list(set(ClassA.index).intersection(set(Quadrant1.index)))
ClassAQuadrant1=Quadrant1.loc[classAQ1]
ClassAQuadrant1.to_csv("ClassAQuadrant1.csv")
classAQ2=list(set(ClassA.index).intersection(set(Quadrant2.index)))
ClassAQuadrant2=Quadrant2.loc[classAQ2]
ClassAQuadrant2.to_csv("ClassAQuadrant2.csv")
classAQ3=list(set(ClassA.index).intersection(set(Quadrant3.index)))
ClassAQuadrant3=Quadrant3.loc[classAQ3]
ClassAQuadrant3.to_csv("ClassAQuadrant3.csv")
classAQ4=list(set(ClassA.index).intersection(set(Quadrant4.index)))
ClassAQuadrant4=Quadrant4.loc[classAQ4]
ClassAQuadrant4.to_csv("ClassAQuadrant4.csv")

# %%
MetabolicCoefVar['Quadrant']=FilteredMetabolicVS.Quadrant
MetabolicCoefVar.to_csv("QuadrantVSCV.csv")

# %%
RegulatedGenes=pd.read_csv("Differentiallyenriched_Regulated_p0.01.csv",index_col=0)

# %%
RegulatedGenes.columns
# Out:
# Index(['Phenotype ID', 'Observed', 'Expected', 'Enrichment fold change',
#        'BH FDR corrected P-value', '-log10(BH FDR-corrected p-value)'],
#       dtype='object')

# %% [markdown]
# ## Total Class A Regulated genes patwhay enrichment

# %%
EnrichedWormPathsClassARegulated=pd.read_csv("TotalClassAMetabolic_PEAStats.txt",sep='\t',index_col=1)

# %%
EnrichedWormPathsClassARegulated=EnrichedWormPathsClassARegulated[~EnrichedWormPathsClassARegulated.index.duplicated(keep='first')]

# %%
import statsmodels as st
# import statsmodels.api as sm
pvalse=EnrichedWormPathsClassARegulated.p_enrichment
EnrichedWormPathsClassARegulated['FDR-corrected p-enrichment']=(st.stats.multitest.fdrcorrection(pvalse, alpha=0.05, method='indep', 
                                                                                           is_sorted=False))[1]

# %%
SignificantPathwayEnrichment= EnrichedWormPathsClassARegulated[EnrichedWormPathsClassARegulated['p_enrichment']<=0.3]

# %%
SignificantPathwayEnrichment.index
# Out:
# Index(['UGT ENZYME', 'LIPIDS', 'GUANYLATE CYCLASE',
#        'NICOTINATE AND NICOTINAMIDE METABOLISM', 'STEROID METABOLISM',
#        'BIOSYNTHESIS OF BILE ACID-LIKE MOLECULES',
#        'PEROXISOMAL FATTY ACID DEGRADATION', 'OTHER AMINO ACIDS',
#        'AMINO ACIDS', 'SULFUR METABOLISM', 'FATTY ACID DEGRADATION',
#        'SPHINGOLIPID METABOLISM', 'MOLYBDENUM COFACTOR BIOSYNTHESIS',
#        'GLYCEROPHOSPHOLIPID METABOLISM', 'FOLATE BIOSYNTHESIS',
#        'COFACTORS AND VITAMINS', 'PYRIMIDINE METABOLISM', 'OTHER',
#        'TAURINE AND HYPOTAURINE METABOLISM', 'SELENOCOMPOUND METABOLISM',
#        'TYROSINE METABOLISM', 'CYS AND MET METABOLISM', 'NUCLEOTIDES',
#        'ALA, ASP/ASN AND GLU/GLN METABOLISM', 'CYSTEINE METABOLISM',
#        'ETHER LIPID METABOLISM', 'GALACTOSE METABOLISM',
#        'RIBOFLAVIN METABOLISM', 'GLYOXYLATE AND DICARBOXYLATE METABOLISM',
#        'PROPIONATE DEGRADATION SHUNT', 'VALINE DEGRADATION',
#        'HISTIDINE DEGRADATION', 'FOLATE CYCLE', 'ONE CARBON CYCLE',
#        'FATTY ACID BIOSYNTHESIS OTHER', 'FATTY ACID BIOSYNTHESIS',
#        'ALANINE METABOLISM', 'PURINE METABOLISM', 'GLUTATHIONE METABOLISM',
#        'MITOCHONDRIAL FATTY ACID DEGRADATION', 'MUFA BIOSYNTHESIS'],
#       dtype='object', name='Category')

# %%
SignificantPathwayEnrichment=SignificantPathwayEnrichment.loc[['LIPIDS','STEROID METABOLISM','BIOSYNTHESIS OF BILE ACID-LIKE MOLECULES',
       'PEROXISOMAL FATTY ACID DEGRADATION','FATTY ACID DEGRADATION',
       'SPHINGOLIPID METABOLISM','GLYCEROPHOSPHOLIPID METABOLISM','ETHER LIPID METABOLISM','FATTY ACID BIOSYNTHESIS OTHER',
                                                               'FATTY ACID BIOSYNTHESIS','MITOCHONDRIAL FATTY ACID DEGRADATION']]

# %%
def SignificantPathwayEnrichmentF(ClassAQuadrant1Pathway):
    PathwayEnrichmentRegulated1=ClassAQuadrant1Pathway[~ClassAQuadrant1Pathway.index.duplicated(keep='first')]
    pvalse=PathwayEnrichmentRegulated1.p_enrichment
    PathwayEnrichmentRegulated1['FDR-corrected p-enrichment']=(st.stats.multitest.fdrcorrection(pvalse, alpha=0.05, method='indep', 
                                                                                           is_sorted=False))[1]
    SignificantPathwayEnrichment1=PathwayEnrichmentRegulated1[['Enrichment score (n_Hits/n_Genes)',
                                                           'p_enrichment','FDR-corrected p-enrichment']]
    SignificantPathwayEnrichment1['-log10(p-enrichment)']=-(np.log10(SignificantPathwayEnrichment1['p_enrichment']))
    
    return SignificantPathwayEnrichment1

def PlotSignificantPathwayEnrichment(SignificantPathwayEnrichment1,title,cutoff):
    import seaborn as sns
    SignificantPathwayEnrichment1=SignificantPathwayEnrichment1[(SignificantPathwayEnrichment1['p_enrichment']<=cutoff)]
    g = SignificantPathwayEnrichment1.reset_index()
    survival_rates = g['Enrichment score (n_Hits/n_Genes)'].mean()
    n = g['-log10(p-enrichment)']

    norm = plt.Normalize(0,1)
    sm = plt.cm.ScalarMappable(cmap="Oranges", norm=norm)
    sm.set_array([])

    ax = sns.barplot(x='-log10(p-enrichment)', y='Category', 
                 hue='Enrichment score (n_Hits/n_Genes)', palette='Oranges', 
                 dodge=False,data=g)

    ax.set_ylabel('WormPaths Pathway/Category ')
    plt.xlim(0,16)

    ax.get_legend().remove()
    from matplotlib import rcParams
    rcParams['font.family'] = 'Arial'
    plt.tight_layout()
    ax.figure.colorbar(sm)
    plt.savefig("WormPathsEnrichment_{}.svg".format(title),dpi=300)

# %%
SignificantPathwayEnrichment
# Out:
#                                             Level  n_Genes  n_Hits  \
# Category
# LIPIDS                                    LEVEL 1      293     231
# STEROID METABOLISM                        LEVEL 2       35      32
# BIOSYNTHESIS OF BILE ACID-LIKE MOLECULES  LEVEL 3       33      30
# PEROXISOMAL FATTY ACID DEGRADATION        LEVEL 3       12      12
# FATTY ACID DEGRADATION                    LEVEL 2       57      46
# SPHINGOLIPID METABOLISM                   LEVEL 2       45      37
# GLYCEROPHOSPHOLIPID METABOLISM            LEVEL 2       96      74
# ETHER LIPID METABOLISM                    LEVEL 2       30      24
# FATTY ACID BIOSYNTHESIS OTHER             LEVEL 4       24      19
# FATTY ACID BIOSYNTHESIS                   LEVEL 2       42      32
# MITOCHONDRIAL FATTY ACID DEGRADATION      LEVEL 3       37      28
#
#                                           Enrichment score (n_Hits/n_Genes)  \
# Category
# LIPIDS                                                                 0.79
# STEROID METABOLISM                                                     0.91
# BIOSYNTHESIS OF BILE ACID-LIKE MOLECULES                               0.91
# PEROXISOMAL FATTY ACID DEGRADATION                                     1.00
# FATTY ACID DEGRADATION                                                 0.81
# SPHINGOLIPID METABOLISM                                                0.82
# GLYCEROPHOSPHOLIPID METABOLISM                                         0.77
# ETHER LIPID METABOLISM                                                 0.80
# FATTY ACID BIOSYNTHESIS OTHER                                          0.79
# FATTY ACID BIOSYNTHESIS                                                0.76
# MITOCHONDRIAL FATTY ACID DEGRADATION                                   0.76
#
#                                           p_enrichment  p_depletion  \
# Category
# LIPIDS                                        0.000025         1.00
# STEROID METABOLISM                            0.001700         1.00
# BIOSYNTHESIS OF BILE ACID-LIKE MOLECULES      0.003000         1.00
# PEROXISOMAL FATTY ACID DEGRADATION            0.012000         1.00
# FATTY ACID DEGRADATION                        0.035000         0.98
# SPHINGOLIPID METABOLISM                       0.035000         0.99
# GLYCEROPHOSPHOLIPID METABOLISM                0.051000         0.97
# ETHER LIPID METABOLISM                        0.140000         0.94
# FATTY ACID BIOSYNTHESIS OTHER                 0.200000         0.90
# FATTY ACID BIOSYNTHESIS                       0.210000         0.88
# MITOCHONDRIAL FATTY ACID DEGRADATION          0.250000         0.85
#
#                                                                                        Hits  \
# Category
# LIPIDS                                    B0024.13;B0272.3;B0272.4;B0395.3;C07E3.9;C17C3...
# STEROID METABOLISM                        B0024.13;C24A3.4;C31H5.6;F25E2.3;F35C8.5;F42F1...
# BIOSYNTHESIS OF BILE ACID-LIKE MOLECULES  C24A3.4;C31H5.6;F25E2.3;F35C8.5;F53F1.2;F53F1....
# PEROXISOMAL FATTY ACID DEGRADATION        F53C11.3;F58A6.1;acox-1.1;acox-1.2;acox-1.3;ac...
# FATTY ACID DEGRADATION                    B0272.3;B0272.4;B0395.3;F53C11.3;F54C8.1;F58A6...
# SPHINGOLIPID METABOLISM                   C29E4.10;F33D4.4;R05D11.9;R08F11.1;T28D9.3;W02...
# GLYCEROPHOSPHOLIPID METABOLISM            C07E3.9;C27A2.12;C27A7.5;C34C6.4;C39D10.3;F02E...
# ETHER LIPID METABOLISM                    C07E3.9;C27A7.1;C27A7.3;C27A7.5;F09G2.8;F13H10...
# FATTY ACID BIOSYNTHESIS OTHER             C17C3.1;C17C3.3;C31H5.6;C37H5.13;F25E2.3;K05B2...
# FATTY ACID BIOSYNTHESIS                   C17C3.1;C17C3.3;C31H5.6;C37H5.13;F25E2.3;K05B2...
# MITOCHONDRIAL FATTY ACID DEGRADATION      B0272.3;B0272.4;B0395.3;F54C8.1;T20B3.1;Y48A6B...
#
#                                           FDR-corrected p-enrichment
# Category
# LIPIDS                                                      0.001362
# STEROID METABOLISM                                          0.037060
# BIOSYNTHESIS OF BILE ACID-LIKE MOLECULES                    0.054500
# PEROXISOMAL FATTY ACID DEGRADATION                          0.186857
# FATTY ACID DEGRADATION                                      0.301846
# SPHINGOLIPID METABOLISM                                     0.301846
# GLYCEROPHOSPHOLIPID METABOLISM                              0.377867
# ETHER LIPID METABOLISM                                      0.545000
# FATTY ACID BIOSYNTHESIS OTHER                               0.622857
# FATTY ACID BIOSYNTHESIS                                     0.635833
# MITOCHONDRIAL FATTY ACID DEGRADATION                        0.681250

# %%
SignificantPathwayEnrichment=SignificantPathwayEnrichmentF(SignificantPathwayEnrichment)
# Out:
# /home/nandas/miniconda3/envs/metabolism/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
PlotSignificantPathwayEnrichment(SignificantPathwayEnrichment,title='ClassAOverallRegulated',cutoff=0.05)

# %% [markdown]
# ## Pathways enriched in 25% of the regulated

# %%
EnrichedPathwaysModeratelyVariant=pd.read_csv("ModeratelyVariant_PathwayEnrich.csv",index_col=0)

# %%
Enri
# Out:
# Index(['Category', 'n_Genes', 'n_Hits', 'Enrichment score (n_Hits/n_Genes)',
#        'p_enrichment', '-log10(p_enrichment)', 'p_depletion',
#        '-log10(p_depletion)', 'Hits'],
#       dtype='object')

# %%
EnrichedPathwaysModeratelyVariant=EnrichedPathwaysModeratelyVariant[EnrichedPathwaysModeratelyVariant.index=='LEVEL 4']

# %%
EnrichedPathwaysModeratelyVariant.sort_values(ascending=False,inplace=True,by=['-log10(p_enrichment)'])

# %%
EnrichedPathwaysModeratelyVariant=EnrichedPathwaysModeratelyVariant[EnrichedPathwaysModeratelyVariant.p_enrichment<=0.05]

# %%
EnrichedPathwaysModeratelyVariant
# Out:
#                             Category  n_Genes  n_Hits  \
# Level
# LEVEL 2     ELECTRON TRANSPORT CHAIN       88      79
# LEVEL 1                       ENERGY      139      96
# LEVEL 3                ETC-COMPLEX I       40      39
# LEVEL 4                ETC-COMPLEX I       40      39
# LEVEL 2  AMINOACYL-TRNA BIOSYNTHESIS       39      26
# LEVEL 3  AMINOACYL-TRNA BIOSYNTHESIS       39      26
# LEVEL 4  AMINOACYL-TRNA BIOSYNTHESIS       39      26
# LEVEL 3                ETC-COMPLEX V       18      15
# LEVEL 4                ETC-COMPLEX V       18      15
# LEVEL 3               ETC-COMPLEX IV       14      12
# LEVEL 4               ETC-COMPLEX IV       14      12
# LEVEL 3              ETC-COMPLEX III       13      10
# LEVEL 4              ETC-COMPLEX III       13      10
# LEVEL 4        MEVALONATE METABOLISM        8       7
# LEVEL 3        MEVALONATE METABOLISM        8       7
# LEVEL 2        MEVALONATE METABOLISM        8       7
# LEVEL 2     TRICARBOXYLIC ACID CYCLE       30      17
# LEVEL 3     TRICARBOXYLIC ACID CYCLE       30      17
# LEVEL 4     TRICARBOXYLIC ACID CYCLE       30      17
# LEVEL 2   GLYCOLYSIS/GLUCONEOGENESIS       44      22
# LEVEL 3   GLYCOLYSIS/GLUCONEOGENESIS       44      22
# LEVEL 4   GLYCOLYSIS/GLUCONEOGENESIS       44      22
#
#          Enrichment score (n_Hits/n_Genes)  p_enrichment  \
# Level
# LEVEL 2                               0.90  8.600000e-33
# LEVEL 1                               0.69  1.300000e-22
# LEVEL 3                               0.97  1.200000e-19
# LEVEL 4                               0.97  1.200000e-19
# LEVEL 2                               0.67  3.600000e-06
# LEVEL 3                               0.67  3.600000e-06
# LEVEL 4                               0.67  3.600000e-06
# LEVEL 3                               0.83  6.000000e-06
# LEVEL 4                               0.83  6.000000e-06
# LEVEL 3                               0.86  3.400000e-05
# LEVEL 4                               0.86  3.400000e-05
# LEVEL 3                               0.77  8.300000e-04
# LEVEL 4                               0.77  8.300000e-04
# LEVEL 4                               0.88  1.600000e-03
# LEVEL 3                               0.88  1.600000e-03
# LEVEL 2                               0.88  1.600000e-03
# LEVEL 2                               0.57  2.900000e-03
# LEVEL 3                               0.57  2.900000e-03
# LEVEL 4                               0.57  2.900000e-03
# LEVEL 2                               0.50  5.800000e-03
# LEVEL 3                               0.50  5.800000e-03
# LEVEL 4                               0.50  5.800000e-03
#
#          -log10(p_enrichment)  p_depletion  -log10(p_depletion)  \
# Level
# LEVEL 2                 32.10          1.0                  0.0
# LEVEL 1                 21.90          1.0                  0.0
# LEVEL 3                 18.90          1.0                  0.0
# LEVEL 4                 18.90          1.0                  0.0
# LEVEL 2                  5.44          1.0                  0.0
g = EnrichedPathwaysModeratelyVariant.reset_index()
survival_rates = g['Enrichment score (n_Hits/n_Genes)'].mean()
n = g['-log10(p_enrichment)']
# cMAP=sns.diverging_palette(220, 20, as_cmap=True)

norm = plt.Normalize(g['Enrichment score (n_Hits/n_Genes)'].min(), g['Enrichment score (n_Hits/n_Genes)'].max())
sm = plt.cm.ScalarMappable(cmap="Oranges", norm=norm)
sm.set_array([])

ax = sns.barplot(x='-log10(p_enrichment)', y='Category', 
                 hue='Enrichment score (n_Hits/n_Genes)', palette="Oranges", 
                 dodge=False,data=g)

ax.set_ylabel('Category')

ax.get_legend().remove()
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'
plt.tight_layout()
ax.figure.colorbar(sm)
plt.savefig("ModeratelyVariantPathwayEnrichment.svg",dpi=300)

# %% [markdown]
# ## Phenotypes

# %%
EnrichedPhenotypesModeratelyvariant=pd.read_csv("ModeratelyVariantGenesPhenotypeEnrichment.csv",index_col=0)

# %%
EnrichedPhenotypesModeratelyvariant.columns

# %%
EnrichedPhenotypesModeratelyvariant.sort_values(ascending=False,inplace=True,by=['-log10(BH-FDR Corrected FDR)'])

# %%
fig=plt.figure(figsize=(10,10))
import seaborn as sns
g = EnrichedPhenotypesModeratelyvariant.reset_index()
survival_rates = g['Enrichment fold change'].mean()
n = g['-log10(BH-FDR Corrected FDR)']
# cMAP=sns.diverging_palette(220, 20, as_cmap=True)

norm = plt.Normalize(g['Enrichment fold change'].min(), g['Enrichment fold change'].max())
sm = plt.cm.ScalarMappable(cmap="Oranges", norm=norm)
sm.set_array([])

ax = sns.barplot(x='-log10(BH-FDR Corrected FDR)', y='Phenotype Name', 
                 hue='Enrichment fold change', palette="Oranges", 
                 dodge=False,data=g)

ax.set_ylabel('Phenotype Name')

ax.get_legend().remove()
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'
plt.tight_layout()
ax.figure.colorbar(sm)
plt.savefig("ModeratelyVariantPhenotypeEnrichment.svg",dpi=300)

# %%
DepletedPhenotypes=RegulatedGenes[RegulatedGenes['Enrichment fold change']<1]

# %%
EnrichedPhenotypes=RegulatedGenes[RegulatedGenes['Enrichment fold change']>1]

# %%
EnrichedPhenotypes.columns

# %%
EnrichedPhenotypes.sort_values(ascending=False,inplace=True,by=['-log10(BH FDR-corrected p-value)'])

# %%
DepletedPhenotypes.sort_values(by=['-log10(BH FDR-corrected p-value)'],ascending=False)

# %%
EnrichedDepletedPhenotypes=pd.concat([EnrichedPhenotypes,DepletedPhenotypes])

# %%
EnrichedDepletedPhenotypes.sort_values(ascending=False,inplace=True,by=['-log10(BH FDR-corrected p-value)'])

# %%
EnrichedDepletedPhenotypes

# %%
fig=plt.figure(figsize=(10,10))
import seaborn as sns
g = EnrichedPhenotypes.reset_index()
survival_rates = g['Enrichment fold change'].mean()
n = g['-log10(BH FDR-corrected p-value)']
# cMAP=sns.diverging_palette(220, 20, as_cmap=True)

norm = plt.Normalize(g['Enrichment fold change'].min(), g['Enrichment fold change'].max())
sm = plt.cm.ScalarMappable(cmap="Oranges", norm=norm)
sm.set_array([])

ax = sns.barplot(x='-log10(BH FDR-corrected p-value)', y='Phenotype Name', 
                 hue='Enrichment fold change', palette="Oranges", 
                 dodge=False,data=g)

ax.set_ylabel('Phenotype Name')

ax.get_legend().remove()
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'
plt.tight_layout()
ax.figure.colorbar(sm)
plt.savefig("WormBasePhenotypeEnrichment.svg",dpi=300)

# %%
DepletedPhenotypes.sort_values(ascending=False,inplace=True,by=['-log10(BH FDR-corrected p-value)'])

# %%
DepletedPhenotypes['Enrichment fold change']=1-DepletedPhenotypes['Enrichment fold change']

# %%
fig=plt.figure(figsize=(10,10))
import seaborn as sns
g = DepletedPhenotypes.reset_index()
survival_rates = g['Enrichment fold change'].mean()
n = g['-log10(BH FDR-corrected p-value)']
# cMAP=sns.diverging_palette(220, 20, as_cmap=True)

norm = plt.Normalize(g['Enrichment fold change'].min(), g['Enrichment fold change'].max())
sm = plt.cm.ScalarMappable(cmap="Blues", norm=norm)
sm.set_array([])

ax = sns.barplot(x='-log10(BH FDR-corrected p-value)', y='Phenotype Name', 
                 hue='Enrichment fold change', palette="Blues", 
                 dodge=False,data=g)

ax.set_ylabel('Phenotype Name')

ax.get_legend().remove()
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'
plt.tight_layout()
ax.figure.colorbar(sm)
plt.savefig("WormBasePhenotypeDepleted.svg",dpi=300)

# %%
DepletedPhenotypes['-log10(BH FDR-corrected p-value)']=-1*(DepletedPhenotypes['-log10(BH FDR-corrected p-value)'])

# %%
fig=plt.figure(figsize=(10,10))
import seaborn as sns
g = EnrichedDepletedPhenotypes.reset_index()
survival_rates = g['Enrichment fold change'].mean()
n = g['-log10(BH FDR-corrected p-value)']
# cMAP=sns.diverging_palette(220, 20, as_cmap=True)

norm = plt.Normalize(g['Enrichment fold change'].min(), g['Enrichment fold change'].max())
sm = plt.cm.ScalarMappable(cmap="vlag", norm=norm)
sm.set_array([])

ax = sns.barplot(x='-log10(BH FDR-corrected p-value)', y='Phenotype Name', 
                 hue='Enrichment fold change', palette="vlag", 
                 dodge=False,data=g)

ax.set_ylabel('Phenotype Name')

ax.get_legend().remove()
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'
plt.tight_layout()
ax.figure.colorbar(sm)
plt.savefig("WormBasePhenotypeEnrichmentDepletion.svg",dpi=300)

# %% [markdown]
# ## Quadrant-wise enrichment analysis

# %% [markdown]
# ### WormPaths

# %%
ClassAQuadrant1Pathway=pd.read_csv("ClassAQuadrant1_PEA_Stats.txt",index_col=1,sep='\t')

# %%
ClassAQuadrant1Pathway

# %%
ClassAQuadrant2Pathway=pd.read_csv("ClassAQuadrant2_PEA_Stats.txt",index_col=1,sep='\t')
ClassAQuadrant3Pathway=pd.read_csv("ClassAQuadrant3_PEA_Stats.txt",index_col=1,sep='\t')
ClassAQuadrant4Pathway=pd.read_csv("ClassAQuadrant4_PEA_Stats.txt",index_col=1,sep='\t')

# %%
ClassAQuadrant1Pathway

# %%
def SignificantPathwayEnrichment(ClassAQuadrant1Pathway):
    PathwayEnrichmentRegulated1=ClassAQuadrant1Pathway[~ClassAQuadrant1Pathway.index.duplicated(keep='first')]
    pvalse=PathwayEnrichmentRegulated1.p_enrichment
    PathwayEnrichmentRegulated1['FDR-corrected p-enrichment']=(st.stats.multitest.fdrcorrection(pvalse, alpha=0.05, method='indep', 
                                                                                           is_sorted=False))[1]
    SignificantPathwayEnrichment1=PathwayEnrichmentRegulated1[['Enrichment score (n_Hits/n_Genes)',
                                                           'p_enrichment','FDR-corrected p-enrichment']]
    SignificantPathwayEnrichment1['-log10(p-enrichment)']=-(np.log10(SignificantPathwayEnrichment1['p_enrichment']))
    
    return SignificantPathwayEnrichment1

def PlotSignificantPathwayEnrichment(SignificantPathwayEnrichment1,title):
    import seaborn as sns
    SignificantPathwayEnrichment1=SignificantPathwayEnrichment1[(SignificantPathwayEnrichment1['p_enrichment']<=0.01)]
    g = SignificantPathwayEnrichment1.reset_index()
    survival_rates = g['Enrichment score (n_Hits/n_Genes)'].mean()
    n = g['-log10(p-enrichment)']

    norm = plt.Normalize(0,1)
    sm = plt.cm.ScalarMappable(cmap="Oranges", norm=norm)
    sm.set_array([])

    ax = sns.barplot(x='-log10(p-enrichment)', y='Category', 
                 hue='Enrichment score (n_Hits/n_Genes)', palette='Oranges', 
                 dodge=False,data=g)

    ax.set_ylabel('WormPaths Pathway/Category ')
#     plt.xlim(0,16)

    ax.get_legend().remove()
    from matplotlib import rcParams
    rcParams['font.family'] = 'Arial'
    plt.tight_layout()
    ax.figure.colorbar(sm)
    plt.savefig("WormPathsEnrichment_{}.svg".format(title),dpi=300)

# %%
SignificantPathwayEnrichment1=SignificantPathwayEnrichment(ClassAQuadrant1Pathway)
PlotSignificantPathwayEnrichment(SignificantPathwayEnrichment1,title='ClassAQuadrant1_0.01')

# %%
SignificantPathwayEnrichment2=SignificantPathwayEnrichment(ClassAQuadrant2Pathway)
PlotSignificantPathwayEnrichment(SignificantPathwayEnrichment2,title='ClassAQuadrant2_0.01')

# %%
SignificantPathwayEnrichment2

# %%
PlotSignificantPathwayEnrichment(SignificantPathwayEnrichment1,title='ClassAQuadrant1_0.01')

# %%
SignificantPathwayEnrichment3=SignificantPathwayEnrichment(ClassAQuadrant3Pathway)
PlotSignificantPathwayEnrichment(SignificantPathwayEnrichment3,title='ClassAQuadrant3_0.03')

# %%
SignificantPathwayEnrichment4=SignificantPathwayEnrichment(ClassAQuadrant4Pathway)
PlotSignificantPathwayEnrichment(SignificantPathwayEnrichment4,title='ClassAQuadrant4_0.03')

# %%
SignificantPathwayEnrichment4[0:50]

# %%
SignificantPathwayEnrichment3[]

# %% [markdown]
# ## Regulated genes

# %%
MetabolicRegulatedGenes=pd.read_csv("RegulatedMetabolic_KimTissue_AllDatasets.csv",index_col=0)

# %%
MetabolicRegulatedGenes

# %% [markdown]
# ## Checking which regulated metabolic genes have stress-response variants

# %%
StressResponse=pd.read_csv("StressRespone_genes_direct_and_inferred_for_WBPhenotype_0000067.txt",index_col=0,
                           sep='\t',header=None)

# %%
MetabolicStressResponse=list(set(StressResponse.index).intersection(set(MetabolicRegulatedGenes.index)))

# %%
MetabolicStressResponse=MetabolicRegulatedGenes.loc[MetabolicStressResponse]

# %%
MetabolicStressResponse

# %%
def wb_to_gene(matrix):
    mapper_df=pd.read_csv("/data/nandas/WormBase_282/MasterProteinCodingGenesAnnotation_WS282.csv", header='infer',index_col=1)
    mapper_df=mapper_df.loc[mapper_df.index.dropna()]
    wb_to_gene = {};
    for wb in mapper_df.index:
        wb_to_gene[wb] = str(mapper_df.loc[wb]['GeneName']);
    matrix=matrix.rename(index=wb_to_gene,columns=wb_to_gene)
    return matrix

def gene_to_wb(matrix):
    mapper_df=pd.read_csv("/data/nandas/WormBase_282/MasterProteinCodingGenesAnnotation_WS282.csv", header='infer',index_col=2)
    mapper_df=mapper_df.loc[mapper_df.index.dropna()]
    gene_to_wb = {};
    for gene in mapper_df.index:
        gene_to_wb[gene] = str(mapper_df.loc[gene]['WormBaseID']);
    matrix=matrix.rename(index=gene_to_wb,columns=gene_to_wb)
    return matrix

# %%
MetabolicStressResponse=wb_to_gene(MetabolicStressResponse)

# %%
MetabolicStressResponse=gene_to_wb(MetabolicStressResponse)

# %% [markdown]
# ## Reading CV of all genes across all datasets

# %%
CV_alldatasets=pd.read_csv("/data/nandas/Transcription/AllDatasets_012422/CV_allgenes.csv",index_col=0)

# %%
CV_alldatasets

# %%
MetabolicClasses=pd.read_csv("/data/nandas/MetabolicClasses_August_SN_090221.csv",index_col=0)
metabolicCV=list(set(MetabolicClasses.index).intersection(set(CV_alldatasets.index)))

# %%
metabolicCV

# %%
MetabolicCV=CV_alldatasets.loc[metabolicCV]

# %%
# MetabolicCV=MetabolicCV['Max_CV']

# %%
metabolicCVall=list(set(MetabolicRegulatedGenes.index).intersection(set(CV_alldatasets.index)))
MetabolicRegulated_CV_alldatasets=CV_alldatasets.loc[metabolicCVall]

# %%
MetabolicRegulated_CV_alldatasets.replace(np.NaN,-6,inplace=True)

# %%
MetabolicRegulated_CV_alldatasets

# %%
data=MetabolicRegulated_CV_alldatasets.transpose()
data=wb_to_gene(data)

# %%
data=data.loc['Max_CV']

# %%
data=pd.DataFrame(data)

# %%
data.sort_values(ascending=False,by=['Max_CV'],inplace=True)

# %%
data[data.Max_CV>=0.75]

# %%
data

# %% [markdown]
# ## Adding variation score and Tissue CV to list of regulated metabolic genes

# %%
VS=pd.read_csv(Kim_dir+"BinningVS.csv",index_col=0)

# %%
CoefVar=pd.read_csv(Tissue_dir+"CoefVarHighModTissue.csv",
                    index_col=0)

# %%
MetabolicCV['Variation Score']=VS['Variation Score']

# %%
MetabolicCV['CV across tissues']=CoefVar['CoefVar']

# %%
MetabolicCV=MetabolicCV[['Max_CV','Variation Score','CV across tissues']]

# %%
df=MetabolicCV
normalized_df=(df-df.mean())/df.std()
normalized_df.replace(np.NaN,-6,inplace=True)
normalized_df.rename(columns={'Max_CV':'Max CV across datasets'},inplace=True)

# %%
normalized_df

# %%
# normalized_df=normalized_df.transpose()
mrg=list(set(MetabolicRegulatedGenes.index).intersection(set(normalized_df.index)))
MetabolicRegulatedGenes_CV=normalized_df.loc[mrg]

# %%
sns.clustermap(MetabolicRegulatedGenes_CV,mask=MetabolicRegulatedGenes_CV==-6,
               vmin=-2,vmax=2,cmap='vlag',figsize=(5,30))
plt.tight_layout()

# %%
# Invariantgenes=normalized_df.loc[InvariantCV.index]

# %%
Ivg=list(set())

# %%
normalized_df=normalized_df.transpose()

# %%
normalized_df.min().min()

# %%
MetabolicRegulatedGenes

# %%
sns.clustermap(normalized_df,mask=normalized_df==-6,
               vmin=-2,vmax=2,cmap='vlag',row_cluster=False,figsize=(30,5))
plt.tight_layout()

# %%
VS

# %%
CoefVar

# %%
CoefVar.columns

# %%
data=gene_to_wb(data)

# %%
data['Variation Score']=VS['Variation Score']

# %%
data['CV across tissues']=CoefVar['CoefVar']

# %%
data.rename(columns={'Max_CV':'Max CV across datasets'},inplace=True)

# %%
data.replace(np.NaN,-6,inplace=True)

# %%
data=data.transpose()

# %%
data=wb_to_gene(data)

# %%
sns.clustermap(data,mask=data==-6,
               vmin=0,vmax=2,cmap='YlOrRd',row_cluster=False,figsize=(50,10))
plt.tight_layout()

# %% [markdown]
# ## Plotting invariant genes

# %%
Invariantgenes=pd.read_csv("/data/nandas/Transcription/AllDatasets_012422/Bin1_AllDatasets.csv",index_col=0)

# %%
invariantcv=list(set(Invariantgenes.index).intersection(set(CV_alldatasets.index)))

# %%
InvariantCV=CV_alldatasets.loc[invariantcv]

# %%
InvariantCV.replace(np.NaN,-6,inplace=True)

# %%
data2=InvariantCV.transpose()
data2=wb_to_gene(data2)

# %%
sns.clustermap(data2,mask=data2==-6,
               vmin=0,vmax=0.75,cmap='YlOrRd')
plt.tight_layout()

# %%
data2.index

# %% [markdown]
# ## Lipid enrichment

# %%
PathwayEnrichmentRegulated=pd.read_csv("Lipid_metabolism_PEA.xlsx - lipid.csv",index_col=0)

# %%
PathwayEnrichmentRegulated

# %%
import statsmodels as st
import statsmodels.api as sm
PathwayEnrichmentRegulated=pd.read_csv("Lipid_metabolism_PEA.xlsx - lipid.csv",index_col=0)
PathwayEnrichmentRegulated.set_index(['Category'],inplace=True)
PathwayEnrichmentRegulated=PathwayEnrichmentRegulated[~PathwayEnrichmentRegulated.index.duplicated(keep='first')]
pvalse=PathwayEnrichmentRegulated.p_enrichment
PathwayEnrichmentRegulated['FDR-corrected p-enrichment']=(st.stats.multitest.fdrcorrection(pvalse, alpha=0.05, method='indep', 
                                                                                           is_sorted=False))[1]
SignificantPathwayEnrichment=PathwayEnrichmentRegulated[['Enrichment score (n_Hits/n_Genes)',
                                                           'p_enrichment']]
SignificantPathwayEnrichment['-log10(p-enrichment)']=-(np.log10(SignificantPathwayEnrichment['p_enrichment']))

# %%
SignificantPathwayEnrichment=SignificantPathwayEnrichment[SignificantPathwayEnrichment.p_enrichment<=0.25]

# %%
import seaborn as sns
g = SignificantPathwayEnrichment.reset_index()
survival_rates = g['Enrichment score (n_Hits/n_Genes)'].mean()
n = g['-log10(p-enrichment)']

norm = plt.Normalize(g['Enrichment score (n_Hits/n_Genes)'].min(), g['Enrichment score (n_Hits/n_Genes)'].max())
sm = plt.cm.ScalarMappable(cmap="Oranges", norm=norm)
sm.set_array([])

ax = sns.barplot(x='-log10(p-enrichment)', y='Category', 
                 hue='Enrichment score (n_Hits/n_Genes)', palette='Oranges', 
                 dodge=False,data=g)

ax.set_ylabel('WormPaths Pathway/Category ')

ax.get_legend().remove()
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'
plt.tight_layout()
ax.figure.colorbar(sm)
plt.savefig("WormPathsEnrichment_lipids_alldatasets.svg",dpi=300)
